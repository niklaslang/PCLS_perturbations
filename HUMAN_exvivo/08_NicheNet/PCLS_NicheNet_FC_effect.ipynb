# %% [markdown]
# ## Human PCLS: cellular crosstalk with NicheNetNiklas after Fibrotic Cocktail

# %%
suppressPackageStartupMessages(library(nichenetr))
suppressPackageStartupMessages(library(Seurat))
suppressPackageStartupMessages(library(tidyverse))
suppressPackageStartupMessages(library(patchwork))
suppressPackageStartupMessages(library(data.table))
suppressPackageStartupMessages(library(Matrix))
suppressPackageStartupMessages(library(igraph))
suppressPackageStartupMessages(library(gridExtra))
suppressPackageStartupMessages(library(viridis))

# %%
## set working directory
setwd('/home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/02_figures/ASK_joint/NicheNet/')

# %% [markdown]
# ### Path to required input data

# %%
dge_dir = '/home/niklas/projects/niche_environments_FIBROSIS/PCLS_human/01_data/ASK_joint/DGE_treatment_vs_CC/'
table_dir = '/home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_inputs/'
results_dir = '/home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/'

# %% [markdown]
# ### Load NicheNet models and networks

# %%
## load NicheNet models and networks ##
ligand_target_matrix <- readRDS('/home/niklas/data/nichenet_models/ligand_target_matrix_HUMAN.rds')
lr_network <- readRDS('/home/niklas/data/nichenet_models/ligand_receptor_network_HUMAN.rds')
weighted_networks_lr <- readRDS('/home/niklas/data/nichenet_models/weighted_ligand_receptor_network_HUMAN.rds')

# %% [markdown]
# ### Function to perform NicheNet Ligand activity analysis

# %%
## function to perform ligand activity analysis ##
ligand_activity_analysis <- function(sender_ct, receiver_ct, geneset_oi, 
                            geneset_title,
                            pct_expr_table, pct_thresh = 0.10,
                            pearson_thresh = 0.08){
    
    
    ## retrieve genes expressed by receiver
    expr_genes_receiver = rownames(pct_expr_table[pct_expr_table[, receiver_ct] > pct_thresh, ])
    background_expr_genes = expr_genes_receiver %>% .[. %in% rownames(ligand_target_matrix)]
    
    ## retrieve genes expressed by sender
    list_expr_genes_sender = lapply(sender_ct, function(x){rownames(pct_expr_table[pct_expr_table[, x] > pct_thresh, ])})
    expr_genes_sender = list_expr_genes_sender %>% unlist() %>% unique()
    
    ## status message ##
    print(paste0("Using ", length(geneset_oi), " genes differently regulated genes in ", receiver_ct, " (",
                 geneset_title, ")"))
    
    ### STEP1: Ligand activity analysis ###
    ## Define a set of potential ligands and receptors 
    # retrieve ligands and receptors
    ligands = lr_network %>% pull(from) %>% unique()
    receptors = lr_network %>% pull(to) %>% unique()
    # ligands expressed by sender celltypes
    expr_ligands = intersect(ligands, expr_genes_sender) 
    # receptor expressed by receiver celltypes
    expr_receptors = intersect(receptors, expr_genes_receiver)
    ### status messages ###
    print(paste0("Expressed Ligands ", length(expr_ligands)))
    print(paste0("Expressed Receptors ", length(expr_receptors)))
    
    ## filter ligands
    # only consider ligands with matching receptors (according to NicheNets databases)
    potential_ligands = lr_network %>% filter(from %in% expr_ligands & to %in% expr_receptors) %>%
                        pull(from) %>% unique()
    ### status message ###
    print(paste0("Potential Ligands ", length(potential_ligands)))
    
    ## predict ligand activities
    ligand_activities = predict_ligand_activities(geneset = geneset_oi,
                                                  background_expressed_genes = background_expr_genes,
                                                  ligand_target_matrix = ligand_target_matrix,
                                                  potential_ligands = potential_ligands)

    ## rank ligands by pearson correlation coefficient
    ligand_activities = ligand_activities %>% arrange(-pearson) %>% mutate(rank = rank(desc(pearson)))
    
    # filter consider ligands with pearson's correlation >= pearson_tresh
    ligand_activities = ligand_activities %>% filter(pearson >= pearson_thresh)
    
    ### status message ###
    print(paste0("Top ranked ligands ", length(ligand_activities$test_ligand)))
    
    return(ligand_activities)  
}

# %%
target_gene_prediction <- function(best_upstream_ligands,geneset_oi, target_thresh = 0.33, n_targets = 500){
    
    ## identify ligand targets
    active_ligand_target_links_df = best_upstream_ligands %>% 
                                    lapply(get_weighted_ligand_target_links,geneset = geneset_oi, ligand_target_matrix = ligand_target_matrix, n = n_targets) %>% bind_rows() %>% drop_na()
    active_ligand_target_links = prepare_ligand_target_visualization(ligand_target_df = active_ligand_target_links_df, ligand_target_matrix = ligand_target_matrix, cutoff = target_thresh)
    
    ## reformat data
    order_ligands = intersect(best_upstream_ligands, colnames(active_ligand_target_links)) %>% rev() %>% make.names()
    order_targets = active_ligand_target_links_df$target %>% unique() %>% 
                    intersect(rownames(active_ligand_target_links)) %>% make.names()
    rownames(active_ligand_target_links) = rownames(active_ligand_target_links) %>% make.names() 
    colnames(active_ligand_target_links) = colnames(active_ligand_target_links) %>% make.names() # make.names() for heatmap visualization of genes like H2-T23
    
    ## final ligand-target heatmap
    vis_ligand_target = active_ligand_target_links[order_targets,order_ligands] %>% t()
    
    ## output: ligand-target matrix
    return(vis_ligand_target) 
    
}

# %% [markdown]
# ### Run NicheNet iteratively to detect crosstalk between all cells for FC vs CC

# %%
## read avg expression table
avg_expr <- read.csv(paste0(table_dir, '220207_ASK_joint_Human_PCLS_CC_FC_avg_expr_SCALED.csv'), row.names = 1, check.names = F, header = T)
pct_expr <- read.csv(paste0(table_dir, '220207_ASK_joint_Human_PCLS_CC_FC_pct_expr.csv'), row.names = 1, check.names = F, header = T)

# %%
cell_type_names <- as.vector(colnames(avg_expr))
cell_type_labels <- c('Airway_Epithelium','Alveolar_Epithelium',
                      'capillary_EC', 'vascular_EC', 'lymphatic_EC',
                      'Fibroblasts','SMC_Pericytes',
                      'Macrophages','DC','Mast_cells',
                      'B_cells','Plasma_cells','T_cells','NK_cells')

# %%
## create final results matrix
quant_results_df <- data.frame(matrix(ncol = length(cell_type_names), nrow = length(cell_type_names)))
colnames(quant_results_df) <- cell_type_names # RECEIVER (!!!)
rownames(quant_results_df) <- cell_type_names # SENDER (!!!)
quant_results_df
# Out:
#                     Airway Epithelium Alveolar Epithelium capillary EC
# Airway Epithelium   NA                NA                  NA
# Alveolar Epithelium NA                NA                  NA
# capillary EC        NA                NA                  NA
# vascular EC         NA                NA                  NA
# lymphatic EC        NA                NA                  NA
# Fibroblasts         NA                NA                  NA
# SMC/Pericytes       NA                NA                  NA
# Macrophages         NA                NA                  NA
# DC                  NA                NA                  NA
# Mast cells          NA                NA                  NA
# B cells             NA                NA                  NA
# Plasma cells        NA                NA                  NA
# T cells             NA                NA                  NA
# NK cells            NA                NA                  NA
#                     vascular EC lymphatic EC Fibroblasts SMC/Pericytes
# Airway Epithelium   NA          NA           NA          NA
# Alveolar Epithelium NA          NA           NA          NA
# capillary EC        NA          NA           NA          NA
# vascular EC         NA          NA           NA          NA
# lymphatic EC        NA          NA           NA          NA
# Fibroblasts         NA          NA           NA          NA
# SMC/Pericytes       NA          NA           NA          NA
# Macrophages         NA          NA           NA          NA
# DC                  NA          NA           NA          NA
# Mast cells          NA          NA           NA          NA
# B cells             NA          NA           NA          NA
# Plasma cells        NA          NA           NA          NA
# T cells             NA          NA           NA          NA
# NK cells            NA          NA           NA          NA
#                     Macrophages DC Mast cells B cells Plasma cells T cells
# Airway Epithelium   NA          NA NA         NA      NA           NA
# Alveolar Epithelium NA          NA NA         NA      NA           NA
# capillary EC        NA          NA NA         NA      NA           NA
# vascular EC         NA          NA NA         NA      NA           NA
# lymphatic EC        NA          NA NA         NA      NA           NA
# Fibroblasts         NA          NA NA         NA      NA           NA
# SMC/Pericytes       NA          NA NA         NA      NA           NA
# Macrophages         NA          NA NA         NA      NA           NA
# DC                  NA          NA NA         NA      NA           NA
# Mast cells          NA          NA NA         NA      NA           NA
# B cells             NA          NA NA         NA      NA           NA
# Plasma cells        NA          NA NA         NA      NA           NA
# T cells             NA          NA NA         NA      NA           NA
# NK cells            NA          NA NA         NA      NA           NA
#                     NK cells
# Airway Epithelium   NA
# Alveolar Epithelium NA
# capillary EC        NA
# vascular EC         NA
# lymphatic EC        NA
# Fibroblasts         NA
# SMC/Pericytes       NA
# Macrophages         NA
# DC                  NA
# Mast cells          NA
# B cells             NA
# Plasma cells        NA
# T cells             NA
# NK cells            NA

# %%
qual_results_df <- copy(quant_results_df)
qual_results_df
# Out:
#                     Airway Epithelium Alveolar Epithelium capillary EC
# Airway Epithelium   NA                NA                  NA
# Alveolar Epithelium NA                NA                  NA
# capillary EC        NA                NA                  NA
# vascular EC         NA                NA                  NA
# lymphatic EC        NA                NA                  NA
# Fibroblasts         NA                NA                  NA
# SMC/Pericytes       NA                NA                  NA
# Macrophages         NA                NA                  NA
# DC                  NA                NA                  NA
# Mast cells          NA                NA                  NA
# B cells             NA                NA                  NA
# Plasma cells        NA                NA                  NA
# T cells             NA                NA                  NA
# NK cells            NA                NA                  NA
#                     vascular EC lymphatic EC Fibroblasts SMC/Pericytes
# Airway Epithelium   NA          NA           NA          NA
# Alveolar Epithelium NA          NA           NA          NA
# capillary EC        NA          NA           NA          NA
# vascular EC         NA          NA           NA          NA
# lymphatic EC        NA          NA           NA          NA
# Fibroblasts         NA          NA           NA          NA
# SMC/Pericytes       NA          NA           NA          NA
# Macrophages         NA          NA           NA          NA
# DC                  NA          NA           NA          NA
# Mast cells          NA          NA           NA          NA
# B cells             NA          NA           NA          NA
# Plasma cells        NA          NA           NA          NA
# T cells             NA          NA           NA          NA
# NK cells            NA          NA           NA          NA
#                     Macrophages DC Mast cells B cells Plasma cells T cells
# Airway Epithelium   NA          NA NA         NA      NA           NA
# Alveolar Epithelium NA          NA NA         NA      NA           NA
# capillary EC        NA          NA NA         NA      NA           NA
# vascular EC         NA          NA NA         NA      NA           NA
# lymphatic EC        NA          NA NA         NA      NA           NA
# Fibroblasts         NA          NA NA         NA      NA           NA
# SMC/Pericytes       NA          NA NA         NA      NA           NA
# Macrophages         NA          NA NA         NA      NA           NA
# DC                  NA          NA NA         NA      NA           NA
# Mast cells          NA          NA NA         NA      NA           NA
# B cells             NA          NA NA         NA      NA           NA
# Plasma cells        NA          NA NA         NA      NA           NA
# T cells             NA          NA NA         NA      NA           NA
# NK cells            NA          NA NA         NA      NA           NA
#                     NK cells
# Airway Epithelium   NA
# Alveolar Epithelium NA
# capillary EC        NA
# vascular EC         NA
# lymphatic EC        NA
# Fibroblasts         NA
# SMC/Pericytes       NA
# Macrophages         NA
# DC                  NA
# Mast cells          NA
# B cells             NA
# Plasma cells        NA
# T cells             NA
# NK cells            NA

# %% [markdown]
# ### Run NicheNet

# %%
for(i in 1:length(cell_type_names)){
    
    ## step 1: define RECEIVER and SENDER cells
    all_senders <- cell_type_names
    all_sender_labels <- cell_type_labels
    receiver_ct <- cell_type_names[i]
    receiver_labels <- cell_type_labels[i]
    
    ## step 2: define geneset of interest
    # read dge table
    dge_table <- read.csv(paste0(dge_dir, '211206_PCLS_human_ASK_joint_' , cell_type_labels[i], '_FC_vs_CC_DGE_results.csv'))
    # only significant genes: pval_adj < 0.05
    dge_table = dge_table %>% filter(qval < 0.05)
    # only genes expressed in at least 10% per group
    dge_table = dge_table %>% filter(pct.CCs > 0.1)
    dge_table = dge_table %>% filter(pct.FCs > 0.1)
    # only upregulated genes with log2fc > 0.25
    dge_genes_up = dge_table %>% filter(log2fc > 0.25)
    geneset_oi <- dge_genes_up$gene
    geneset_title <- paste0(cell_type_names[i], ' (FC vs. CC)')
    print(paste0(cell_type_names[i], ' (FC vs. CC): Proceeding with geneset of interest of length: ', length(geneset_oi)))
    
    ## step 3: run ligand activity analysis
    top_ligands_table <- ligand_activity_analysis(all_senders, receiver_ct, geneset_oi = geneset_oi,
                                           geneset_title = geneset_title, pct_thresh = 0.10,
                                           pct_expr_table = pct_expr, pearson_thresh = 0.05)
    
    ## dissect crosstalk between all pairs of cell types quantitatively and qualitatively
    
    # for each sender cell type check which top ligands are upregulated
    for(i in 1:length(all_senders)){
        sender_ct <- all_senders[i]
        sender_label <- all_sender_labels[i]
        # read respective DGE table
        # read dge table
        dge_table <- read.csv(paste0(dge_dir, '211206_PCLS_human_ASK_joint_' , sender_label, '_FC_vs_CC_DGE_results.csv'))
        
        # subset DGE table to top ligands
        ligands_dge = dge_table %>% filter(gene %in% top_ligands_table$test_ligand) 
        
        # filter DGE table by logFC and q-Value
        # if logFC > 0.25 and q-Value < 0.05, a ligand is upregulated
        ligands_dge = ligands_dge %>% filter(qval < 0.05)
        ligands_dge = ligands_dge %>% filter(log2fc > 0.25)
        
        ## add info whether gene is upregulated in SENDER cell type to ligand activity table
        top_ligands_table <- top_ligands_table %>% mutate(new_col = case_when(test_ligand %in% ligands_dge$gene ~ 1,
                                         !(test_ligand %in% ligands_dge$gene) ~ 0))
        colnames(top_ligands_table)[colnames(top_ligands_table) == 'new_col'] <- paste0(sender_label, '_UP')
        
        ### quantitative approach ### 
        # count genes in resulting DGE table --> no. of upregulated top ligands
        ct_quant_score <- length(ligands_dge$gene)
        cat('\n')
        print(paste0(sender_ct, ' --> ', receiver_ct, ' - Top ranked ligands: ', length(top_ligands_table$test_ligand)))
        print(paste0(sender_ct, ' --> ', receiver_ct, ' - Thereof upregulated: ', ct_quant_score))
        cat('\n')
        # fill final results matrix
        quant_results_df[sender_ct, receiver_ct] <- ct_quant_score
        
        ### qualitative approach ### 
        
        # filter ligands results table: upregulated ligands only
        ligands_up = top_ligands_table %>% filter(test_ligand %in% ligands_dge$gene)
        
        # filter avg expression table: only sender cell type
        ligands_avg_expr = avg_expr %>% select(sender_ct)
        # filter avg expression table: only top ligands
        ligands_avg_expr = ligands_avg_expr %>% filter(rownames(ligands_avg_expr) %in% ligands_dge$gene)
        ligands_avg_expr$gene <- rownames(ligands_avg_expr)
        rownames(ligands_avg_expr) <- NULL
        
        # merge ligands results table with ligands avg expression table
        ligands_up <- merge.data.frame(x = ligands_up, y = ligands_avg_expr, by.x = 'test_ligand', by.y = 'gene')
        
        # add new colum to ligand results table: avg expression * ligand score (pearsons rho)
        ligands_up$contribution <- ligands_up[, sender_ct] * ligands_up$pearson
        # sender celltype contribution score equals the sum of the new column
        ct_qual_score <- sum(ligands_up$contribution)
        
        # fill final results matrix
        qual_results_df[sender_ct, receiver_ct] <- ct_qual_score

    }
    
    ## save ligand activity analysis
    print(paste0('Writing ligand activity table to:  ', results_dir, 'nichenet_ligand_act_', receiver_labels, '.csv'))
    write.csv(top_ligands_table, paste0(results_dir, 'nichenet_ligand_act_', receiver_labels, '.csv'))
    
    ## step 4: target gene prediction
    ligand_target_prediction <- target_gene_prediction(best_upstream_ligands = top_ligands_table$test_ligand, geneset_oi = geneset_oi)
    print(paste0('Writing ligand target matrix table to:  ', results_dir, 'nichenet_ligand_target_matrix_', receiver_labels, '.csv'))
    write.csv(ligand_target_prediction, paste0(results_dir, 'nichenet_ligand_target_matrix_', receiver_labels, '.csv'))
}
# Out:
# [1] "Airway Epithelium (FC vs. CC): Proceeding with geneset of interest of length: 469"
# [1] "Using 469 genes differently regulated genes in Airway Epithelium (Airway Epithelium (FC vs. CC))"
# [1] "Expressed Ligands 308"
# [1] "Expressed Receptors 152"
# [1] "Potential Ligands 203"
# [1] "Top ranked ligands 0"
#
# [1] "Airway Epithelium --> Airway Epithelium - Top ranked ligands: 0"
# [1] "Airway Epithelium --> Airway Epithelium - Thereof upregulated: 0"
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(sender_ct)` instead of `sender_ct` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
# [1] "Alveolar Epithelium --> Airway Epithelium - Top ranked ligands: 0"
# [1] "Alveolar Epithelium --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "capillary EC --> Airway Epithelium - Top ranked ligands: 0"
# [1] "capillary EC --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "vascular EC --> Airway Epithelium - Top ranked ligands: 0"
# [1] "vascular EC --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "lymphatic EC --> Airway Epithelium - Top ranked ligands: 0"
# [1] "lymphatic EC --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "Fibroblasts --> Airway Epithelium - Top ranked ligands: 0"
# [1] "Fibroblasts --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "SMC/Pericytes --> Airway Epithelium - Top ranked ligands: 0"
# [1] "SMC/Pericytes --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "Macrophages --> Airway Epithelium - Top ranked ligands: 0"
# [1] "Macrophages --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "DC --> Airway Epithelium - Top ranked ligands: 0"
# [1] "DC --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "Mast cells --> Airway Epithelium - Top ranked ligands: 0"
# [1] "Mast cells --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "B cells --> Airway Epithelium - Top ranked ligands: 0"
# [1] "B cells --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> Airway Epithelium - Top ranked ligands: 0"
# [1] "Plasma cells --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "T cells --> Airway Epithelium - Top ranked ligands: 0"
# [1] "T cells --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "NK cells --> Airway Epithelium - Top ranked ligands: 0"
# [1] "NK cells --> Airway Epithelium - Thereof upregulated: 0"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_Airway_Epithelium.csv"
# Warning message:
# “Unknown or uninitialised column: `weight`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# Warning message:
# “Unknown or uninitialised column: `ligand`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# Warning message:
# “Unknown or uninitialised column: `ligand`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# Warning message:
# “Unknown or uninitialised column: `ligand`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_Airway_Epithelium.csv"
# [1] "Alveolar Epithelium (FC vs. CC): Proceeding with geneset of interest of length: 540"
# [1] "Using 540 genes differently regulated genes in Alveolar Epithelium (Alveolar Epithelium (FC vs. CC))"
# [1] "Expressed Ligands 308"
# [1] "Expressed Receptors 161"
# [1] "Potential Ligands 215"
# [1] "Top ranked ligands 199"
#
# [1] "Airway Epithelium --> Alveolar Epithelium - Top ranked ligands: 199"
# [1] "Airway Epithelium --> Alveolar Epithelium - Thereof upregulated: 27"
#
#
# [1] "Alveolar Epithelium --> Alveolar Epithelium - Top ranked ligands: 199"
# [1] "Alveolar Epithelium --> Alveolar Epithelium - Thereof upregulated: 39"
#
#
# [1] "capillary EC --> Alveolar Epithelium - Top ranked ligands: 199"
# [1] "capillary EC --> Alveolar Epithelium - Thereof upregulated: 31"
#
#
# [1] "vascular EC --> Alveolar Epithelium - Top ranked ligands: 199"
# [1] "vascular EC --> Alveolar Epithelium - Thereof upregulated: 56"
#
#
# [1] "lymphatic EC --> Alveolar Epithelium - Top ranked ligands: 199"
# [1] "lymphatic EC --> Alveolar Epithelium - Thereof upregulated: 17"
#
#
# [1] "Fibroblasts --> Alveolar Epithelium - Top ranked ligands: 199"
# [1] "Fibroblasts --> Alveolar Epithelium - Thereof upregulated: 47"
#
#
# [1] "SMC/Pericytes --> Alveolar Epithelium - Top ranked ligands: 199"
# [1] "SMC/Pericytes --> Alveolar Epithelium - Thereof upregulated: 45"
#
#
# [1] "Macrophages --> Alveolar Epithelium - Top ranked ligands: 199"
# [1] "Macrophages --> Alveolar Epithelium - Thereof upregulated: 37"
#
#
# [1] "DC --> Alveolar Epithelium - Top ranked ligands: 199"
# [1] "DC --> Alveolar Epithelium - Thereof upregulated: 3"
#
#
# [1] "Mast cells --> Alveolar Epithelium - Top ranked ligands: 199"
# [1] "Mast cells --> Alveolar Epithelium - Thereof upregulated: 10"
#
#
# [1] "B cells --> Alveolar Epithelium - Top ranked ligands: 199"
# [1] "B cells --> Alveolar Epithelium - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> Alveolar Epithelium - Top ranked ligands: 199"
# [1] "Plasma cells --> Alveolar Epithelium - Thereof upregulated: 0"
#
#
# [1] "T cells --> Alveolar Epithelium - Top ranked ligands: 199"
# [1] "T cells --> Alveolar Epithelium - Thereof upregulated: 7"
#
#
# [1] "NK cells --> Alveolar Epithelium - Top ranked ligands: 199"
# [1] "NK cells --> Alveolar Epithelium - Thereof upregulated: 6"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_Alveolar_Epithelium.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_Alveolar_Epithelium.csv"
# [1] "capillary EC (FC vs. CC): Proceeding with geneset of interest of length: 1351"
# [1] "Using 1351 genes differently regulated genes in capillary EC (capillary EC (FC vs. CC))"
# [1] "Expressed Ligands 308"
# [1] "Expressed Receptors 109"
# [1] "Potential Ligands 184"
# [1] "Top ranked ligands 0"
#
# [1] "Airway Epithelium --> capillary EC - Top ranked ligands: 0"
# [1] "Airway Epithelium --> capillary EC - Thereof upregulated: 0"
#
#
# [1] "Alveolar Epithelium --> capillary EC - Top ranked ligands: 0"
# [1] "Alveolar Epithelium --> capillary EC - Thereof upregulated: 0"
#
#
# [1] "capillary EC --> capillary EC - Top ranked ligands: 0"
# [1] "capillary EC --> capillary EC - Thereof upregulated: 0"
#
#
# [1] "vascular EC --> capillary EC - Top ranked ligands: 0"
# [1] "vascular EC --> capillary EC - Thereof upregulated: 0"
#
#
# [1] "lymphatic EC --> capillary EC - Top ranked ligands: 0"
# [1] "lymphatic EC --> capillary EC - Thereof upregulated: 0"
#
#
# [1] "Fibroblasts --> capillary EC - Top ranked ligands: 0"
# [1] "Fibroblasts --> capillary EC - Thereof upregulated: 0"
#
#
# [1] "SMC/Pericytes --> capillary EC - Top ranked ligands: 0"
# [1] "SMC/Pericytes --> capillary EC - Thereof upregulated: 0"
#
#
# [1] "Macrophages --> capillary EC - Top ranked ligands: 0"
# [1] "Macrophages --> capillary EC - Thereof upregulated: 0"
#
#
# [1] "DC --> capillary EC - Top ranked ligands: 0"
# [1] "DC --> capillary EC - Thereof upregulated: 0"
#
#
# [1] "Mast cells --> capillary EC - Top ranked ligands: 0"
# [1] "Mast cells --> capillary EC - Thereof upregulated: 0"
#
#
# [1] "B cells --> capillary EC - Top ranked ligands: 0"
# [1] "B cells --> capillary EC - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> capillary EC - Top ranked ligands: 0"
# [1] "Plasma cells --> capillary EC - Thereof upregulated: 0"
#
#
# [1] "T cells --> capillary EC - Top ranked ligands: 0"
# [1] "T cells --> capillary EC - Thereof upregulated: 0"
#
#
# [1] "NK cells --> capillary EC - Top ranked ligands: 0"
# [1] "NK cells --> capillary EC - Thereof upregulated: 0"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_capillary_EC.csv"
# Warning message:
# “Unknown or uninitialised column: `weight`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# Warning message:
# “Unknown or uninitialised column: `ligand`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# Warning message:
# “Unknown or uninitialised column: `ligand`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# Warning message:
# “Unknown or uninitialised column: `ligand`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_capillary_EC.csv"
# [1] "vascular EC (FC vs. CC): Proceeding with geneset of interest of length: 932"
# [1] "Using 932 genes differently regulated genes in vascular EC (vascular EC (FC vs. CC))"
# [1] "Expressed Ligands 308"
# [1] "Expressed Receptors 164"
# [1] "Potential Ligands 205"
# [1] "Top ranked ligands 199"
#
# [1] "Airway Epithelium --> vascular EC - Top ranked ligands: 199"
# [1] "Airway Epithelium --> vascular EC - Thereof upregulated: 31"
#
#
# [1] "Alveolar Epithelium --> vascular EC - Top ranked ligands: 199"
# [1] "Alveolar Epithelium --> vascular EC - Thereof upregulated: 40"
#
#
# [1] "capillary EC --> vascular EC - Top ranked ligands: 199"
# [1] "capillary EC --> vascular EC - Thereof upregulated: 28"
#
#
# [1] "vascular EC --> vascular EC - Top ranked ligands: 199"
# [1] "vascular EC --> vascular EC - Thereof upregulated: 53"
#
#
# [1] "lymphatic EC --> vascular EC - Top ranked ligands: 199"
# [1] "lymphatic EC --> vascular EC - Thereof upregulated: 14"
#
#
# [1] "Fibroblasts --> vascular EC - Top ranked ligands: 199"
# [1] "Fibroblasts --> vascular EC - Thereof upregulated: 41"
#
#
# [1] "SMC/Pericytes --> vascular EC - Top ranked ligands: 199"
# [1] "SMC/Pericytes --> vascular EC - Thereof upregulated: 42"
#
#
# [1] "Macrophages --> vascular EC - Top ranked ligands: 199"
# [1] "Macrophages --> vascular EC - Thereof upregulated: 32"
#
#
# [1] "DC --> vascular EC - Top ranked ligands: 199"
# [1] "DC --> vascular EC - Thereof upregulated: 5"
#
#
# [1] "Mast cells --> vascular EC - Top ranked ligands: 199"
# [1] "Mast cells --> vascular EC - Thereof upregulated: 11"
#
#
# [1] "B cells --> vascular EC - Top ranked ligands: 199"
# [1] "B cells --> vascular EC - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> vascular EC - Top ranked ligands: 199"
# [1] "Plasma cells --> vascular EC - Thereof upregulated: 2"
#
#
# [1] "T cells --> vascular EC - Top ranked ligands: 199"
# [1] "T cells --> vascular EC - Thereof upregulated: 8"
#
#
# [1] "NK cells --> vascular EC - Top ranked ligands: 199"
# [1] "NK cells --> vascular EC - Thereof upregulated: 6"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_vascular_EC.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_vascular_EC.csv"
# [1] "lymphatic EC (FC vs. CC): Proceeding with geneset of interest of length: 122"
# [1] "Using 122 genes differently regulated genes in lymphatic EC (lymphatic EC (FC vs. CC))"
# [1] "Expressed Ligands 308"
# [1] "Expressed Receptors 132"
# [1] "Potential Ligands 196"
# [1] "Top ranked ligands 187"
#
# [1] "Airway Epithelium --> lymphatic EC - Top ranked ligands: 187"
# [1] "Airway Epithelium --> lymphatic EC - Thereof upregulated: 32"
#
#
# [1] "Alveolar Epithelium --> lymphatic EC - Top ranked ligands: 187"
# [1] "Alveolar Epithelium --> lymphatic EC - Thereof upregulated: 40"
#
#
# [1] "capillary EC --> lymphatic EC - Top ranked ligands: 187"
# [1] "capillary EC --> lymphatic EC - Thereof upregulated: 27"
#
#
# [1] "vascular EC --> lymphatic EC - Top ranked ligands: 187"
# [1] "vascular EC --> lymphatic EC - Thereof upregulated: 52"
#
#
# [1] "lymphatic EC --> lymphatic EC - Top ranked ligands: 187"
# [1] "lymphatic EC --> lymphatic EC - Thereof upregulated: 15"
#
#
# [1] "Fibroblasts --> lymphatic EC - Top ranked ligands: 187"
# [1] "Fibroblasts --> lymphatic EC - Thereof upregulated: 40"
#
#
# [1] "SMC/Pericytes --> lymphatic EC - Top ranked ligands: 187"
# [1] "SMC/Pericytes --> lymphatic EC - Thereof upregulated: 40"
#
#
# [1] "Macrophages --> lymphatic EC - Top ranked ligands: 187"
# [1] "Macrophages --> lymphatic EC - Thereof upregulated: 35"
#
#
# [1] "DC --> lymphatic EC - Top ranked ligands: 187"
# [1] "DC --> lymphatic EC - Thereof upregulated: 5"
#
#
# [1] "Mast cells --> lymphatic EC - Top ranked ligands: 187"
# [1] "Mast cells --> lymphatic EC - Thereof upregulated: 9"
#
#
# [1] "B cells --> lymphatic EC - Top ranked ligands: 187"
# [1] "B cells --> lymphatic EC - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> lymphatic EC - Top ranked ligands: 187"
# [1] "Plasma cells --> lymphatic EC - Thereof upregulated: 1"
#
#
# [1] "T cells --> lymphatic EC - Top ranked ligands: 187"
# [1] "T cells --> lymphatic EC - Thereof upregulated: 8"
#
#
# [1] "NK cells --> lymphatic EC - Top ranked ligands: 187"
# [1] "NK cells --> lymphatic EC - Thereof upregulated: 5"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_lymphatic_EC.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_lymphatic_EC.csv"
# [1] "Fibroblasts (FC vs. CC): Proceeding with geneset of interest of length: 240"
# [1] "Using 240 genes differently regulated genes in Fibroblasts (Fibroblasts (FC vs. CC))"
# [1] "Expressed Ligands 308"
# [1] "Expressed Receptors 146"
# [1] "Potential Ligands 221"
# [1] "Top ranked ligands 213"
#
# [1] "Airway Epithelium --> Fibroblasts - Top ranked ligands: 213"
# [1] "Airway Epithelium --> Fibroblasts - Thereof upregulated: 29"
#
#
# [1] "Alveolar Epithelium --> Fibroblasts - Top ranked ligands: 213"
# [1] "Alveolar Epithelium --> Fibroblasts - Thereof upregulated: 45"
#
#
# [1] "capillary EC --> Fibroblasts - Top ranked ligands: 213"
# [1] "capillary EC --> Fibroblasts - Thereof upregulated: 33"
#
#
# [1] "vascular EC --> Fibroblasts - Top ranked ligands: 213"
# [1] "vascular EC --> Fibroblasts - Thereof upregulated: 58"
#
#
# [1] "lymphatic EC --> Fibroblasts - Top ranked ligands: 213"
# [1] "lymphatic EC --> Fibroblasts - Thereof upregulated: 17"
#
#
# [1] "Fibroblasts --> Fibroblasts - Top ranked ligands: 213"
# [1] "Fibroblasts --> Fibroblasts - Thereof upregulated: 46"
#
#
# [1] "SMC/Pericytes --> Fibroblasts - Top ranked ligands: 213"
# [1] "SMC/Pericytes --> Fibroblasts - Thereof upregulated: 46"
#
#
# [1] "Macrophages --> Fibroblasts - Top ranked ligands: 213"
# [1] "Macrophages --> Fibroblasts - Thereof upregulated: 37"
#
#
# [1] "DC --> Fibroblasts - Top ranked ligands: 213"
# [1] "DC --> Fibroblasts - Thereof upregulated: 4"
#
#
# [1] "Mast cells --> Fibroblasts - Top ranked ligands: 213"
# [1] "Mast cells --> Fibroblasts - Thereof upregulated: 10"
#
#
# [1] "B cells --> Fibroblasts - Top ranked ligands: 213"
# [1] "B cells --> Fibroblasts - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> Fibroblasts - Top ranked ligands: 213"
# [1] "Plasma cells --> Fibroblasts - Thereof upregulated: 1"
#
#
# [1] "T cells --> Fibroblasts - Top ranked ligands: 213"
# [1] "T cells --> Fibroblasts - Thereof upregulated: 8"
#
#
# [1] "NK cells --> Fibroblasts - Top ranked ligands: 213"
# [1] "NK cells --> Fibroblasts - Thereof upregulated: 5"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_Fibroblasts.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_Fibroblasts.csv"
# [1] "SMC/Pericytes (FC vs. CC): Proceeding with geneset of interest of length: 344"
# [1] "Using 344 genes differently regulated genes in SMC/Pericytes (SMC/Pericytes (FC vs. CC))"
# [1] "Expressed Ligands 308"
# [1] "Expressed Receptors 169"
# [1] "Potential Ligands 235"
# [1] "Top ranked ligands 225"
#
# [1] "Airway Epithelium --> SMC/Pericytes - Top ranked ligands: 225"
# [1] "Airway Epithelium --> SMC/Pericytes - Thereof upregulated: 31"
#
#
# [1] "Alveolar Epithelium --> SMC/Pericytes - Top ranked ligands: 225"
# [1] "Alveolar Epithelium --> SMC/Pericytes - Thereof upregulated: 45"
#
#
# [1] "capillary EC --> SMC/Pericytes - Top ranked ligands: 225"
# [1] "capillary EC --> SMC/Pericytes - Thereof upregulated: 33"
#
#
# [1] "vascular EC --> SMC/Pericytes - Top ranked ligands: 225"
# [1] "vascular EC --> SMC/Pericytes - Thereof upregulated: 61"
#
#
# [1] "lymphatic EC --> SMC/Pericytes - Top ranked ligands: 225"
# [1] "lymphatic EC --> SMC/Pericytes - Thereof upregulated: 17"
#
#
# [1] "Fibroblasts --> SMC/Pericytes - Top ranked ligands: 225"
# [1] "Fibroblasts --> SMC/Pericytes - Thereof upregulated: 48"
#
#
# [1] "SMC/Pericytes --> SMC/Pericytes - Top ranked ligands: 225"
# [1] "SMC/Pericytes --> SMC/Pericytes - Thereof upregulated: 49"
#
#
# [1] "Macrophages --> SMC/Pericytes - Top ranked ligands: 225"
# [1] "Macrophages --> SMC/Pericytes - Thereof upregulated: 38"
#
#
# [1] "DC --> SMC/Pericytes - Top ranked ligands: 225"
# [1] "DC --> SMC/Pericytes - Thereof upregulated: 4"
#
#
# [1] "Mast cells --> SMC/Pericytes - Top ranked ligands: 225"
# [1] "Mast cells --> SMC/Pericytes - Thereof upregulated: 11"
#
#
# [1] "B cells --> SMC/Pericytes - Top ranked ligands: 225"
# [1] "B cells --> SMC/Pericytes - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> SMC/Pericytes - Top ranked ligands: 225"
# [1] "Plasma cells --> SMC/Pericytes - Thereof upregulated: 2"
#
#
# [1] "T cells --> SMC/Pericytes - Top ranked ligands: 225"
# [1] "T cells --> SMC/Pericytes - Thereof upregulated: 8"
#
#
# [1] "NK cells --> SMC/Pericytes - Top ranked ligands: 225"
# [1] "NK cells --> SMC/Pericytes - Thereof upregulated: 7"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_SMC_Pericytes.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_SMC_Pericytes.csv"
# [1] "Macrophages (FC vs. CC): Proceeding with geneset of interest of length: 557"
# [1] "Using 557 genes differently regulated genes in Macrophages (Macrophages (FC vs. CC))"
# [1] "Expressed Ligands 308"
# [1] "Expressed Receptors 164"
# [1] "Potential Ligands 209"
# [1] "Top ranked ligands 200"
#
# [1] "Airway Epithelium --> Macrophages - Top ranked ligands: 200"
# [1] "Airway Epithelium --> Macrophages - Thereof upregulated: 32"
#
#
# [1] "Alveolar Epithelium --> Macrophages - Top ranked ligands: 200"
# [1] "Alveolar Epithelium --> Macrophages - Thereof upregulated: 40"
#
#
# [1] "capillary EC --> Macrophages - Top ranked ligands: 200"
# [1] "capillary EC --> Macrophages - Thereof upregulated: 27"
#
#
# [1] "vascular EC --> Macrophages - Top ranked ligands: 200"
# [1] "vascular EC --> Macrophages - Thereof upregulated: 56"
#
#
# [1] "lymphatic EC --> Macrophages - Top ranked ligands: 200"
# [1] "lymphatic EC --> Macrophages - Thereof upregulated: 20"
#
#
# [1] "Fibroblasts --> Macrophages - Top ranked ligands: 200"
# [1] "Fibroblasts --> Macrophages - Thereof upregulated: 42"
#
#
# [1] "SMC/Pericytes --> Macrophages - Top ranked ligands: 200"
# [1] "SMC/Pericytes --> Macrophages - Thereof upregulated: 46"
#
#
# [1] "Macrophages --> Macrophages - Top ranked ligands: 200"
# [1] "Macrophages --> Macrophages - Thereof upregulated: 35"
#
#
# [1] "DC --> Macrophages - Top ranked ligands: 200"
# [1] "DC --> Macrophages - Thereof upregulated: 4"
#
#
# [1] "Mast cells --> Macrophages - Top ranked ligands: 200"
# [1] "Mast cells --> Macrophages - Thereof upregulated: 13"
#
#
# [1] "B cells --> Macrophages - Top ranked ligands: 200"
# [1] "B cells --> Macrophages - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> Macrophages - Top ranked ligands: 200"
# [1] "Plasma cells --> Macrophages - Thereof upregulated: 2"
#
#
# [1] "T cells --> Macrophages - Top ranked ligands: 200"
# [1] "T cells --> Macrophages - Thereof upregulated: 7"
#
#
# [1] "NK cells --> Macrophages - Top ranked ligands: 200"
# [1] "NK cells --> Macrophages - Thereof upregulated: 7"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_Macrophages.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_Macrophages.csv"
# [1] "DC (FC vs. CC): Proceeding with geneset of interest of length: 58"
# [1] "Using 58 genes differently regulated genes in DC (DC (FC vs. CC))"
# [1] "Expressed Ligands 308"
# [1] "Expressed Receptors 96"
# [1] "Potential Ligands 163"
# [1] "Top ranked ligands 82"
#
# [1] "Airway Epithelium --> DC - Top ranked ligands: 82"
# [1] "Airway Epithelium --> DC - Thereof upregulated: 17"
#
#
# [1] "Alveolar Epithelium --> DC - Top ranked ligands: 82"
# [1] "Alveolar Epithelium --> DC - Thereof upregulated: 15"
#
#
# [1] "capillary EC --> DC - Top ranked ligands: 82"
# [1] "capillary EC --> DC - Thereof upregulated: 14"
#
#
# [1] "vascular EC --> DC - Top ranked ligands: 82"
# [1] "vascular EC --> DC - Thereof upregulated: 21"
#
#
# [1] "lymphatic EC --> DC - Top ranked ligands: 82"
# [1] "lymphatic EC --> DC - Thereof upregulated: 6"
#
#
# [1] "Fibroblasts --> DC - Top ranked ligands: 82"
# [1] "Fibroblasts --> DC - Thereof upregulated: 20"
#
#
# [1] "SMC/Pericytes --> DC - Top ranked ligands: 82"
# [1] "SMC/Pericytes --> DC - Thereof upregulated: 16"
#
#
# [1] "Macrophages --> DC - Top ranked ligands: 82"
# [1] "Macrophages --> DC - Thereof upregulated: 20"
#
#
# [1] "DC --> DC - Top ranked ligands: 82"
# [1] "DC --> DC - Thereof upregulated: 2"
#
#
# [1] "Mast cells --> DC - Top ranked ligands: 82"
# [1] "Mast cells --> DC - Thereof upregulated: 4"
#
#
# [1] "B cells --> DC - Top ranked ligands: 82"
# [1] "B cells --> DC - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> DC - Top ranked ligands: 82"
# [1] "Plasma cells --> DC - Thereof upregulated: 0"
#
#
# [1] "T cells --> DC - Top ranked ligands: 82"
# [1] "T cells --> DC - Thereof upregulated: 5"
#
#
# [1] "NK cells --> DC - Top ranked ligands: 82"
# [1] "NK cells --> DC - Thereof upregulated: 4"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_DC.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_DC.csv"
# [1] "Mast cells (FC vs. CC): Proceeding with geneset of interest of length: 266"
# [1] "Using 266 genes differently regulated genes in Mast cells (Mast cells (FC vs. CC))"
# [1] "Expressed Ligands 308"
# [1] "Expressed Receptors 45"
# [1] "Potential Ligands 120"
# [1] "Top ranked ligands 23"
#
# [1] "Airway Epithelium --> Mast cells - Top ranked ligands: 23"
# [1] "Airway Epithelium --> Mast cells - Thereof upregulated: 2"
#
#
# [1] "Alveolar Epithelium --> Mast cells - Top ranked ligands: 23"
# [1] "Alveolar Epithelium --> Mast cells - Thereof upregulated: 4"
#
#
# [1] "capillary EC --> Mast cells - Top ranked ligands: 23"
# [1] "capillary EC --> Mast cells - Thereof upregulated: 3"
#
#
# [1] "vascular EC --> Mast cells - Top ranked ligands: 23"
# [1] "vascular EC --> Mast cells - Thereof upregulated: 7"
#
#
# [1] "lymphatic EC --> Mast cells - Top ranked ligands: 23"
# [1] "lymphatic EC --> Mast cells - Thereof upregulated: 3"
#
#
# [1] "Fibroblasts --> Mast cells - Top ranked ligands: 23"
# [1] "Fibroblasts --> Mast cells - Thereof upregulated: 5"
#
#
# [1] "SMC/Pericytes --> Mast cells - Top ranked ligands: 23"
# [1] "SMC/Pericytes --> Mast cells - Thereof upregulated: 7"
#
#
# [1] "Macrophages --> Mast cells - Top ranked ligands: 23"
# [1] "Macrophages --> Mast cells - Thereof upregulated: 5"
#
#
# [1] "DC --> Mast cells - Top ranked ligands: 23"
# [1] "DC --> Mast cells - Thereof upregulated: 1"
#
#
# [1] "Mast cells --> Mast cells - Top ranked ligands: 23"
# [1] "Mast cells --> Mast cells - Thereof upregulated: 3"
#
#
# [1] "B cells --> Mast cells - Top ranked ligands: 23"
# [1] "B cells --> Mast cells - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> Mast cells - Top ranked ligands: 23"
# [1] "Plasma cells --> Mast cells - Thereof upregulated: 0"
#
#
# [1] "T cells --> Mast cells - Top ranked ligands: 23"
# [1] "T cells --> Mast cells - Thereof upregulated: 0"
#
#
# [1] "NK cells --> Mast cells - Top ranked ligands: 23"
# [1] "NK cells --> Mast cells - Thereof upregulated: 1"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_Mast_cells.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_Mast_cells.csv"
# [1] "B cells (FC vs. CC): Proceeding with geneset of interest of length: 5"
# [1] "Using 5 genes differently regulated genes in B cells (B cells (FC vs. CC))"
# [1] "Expressed Ligands 308"
# [1] "Expressed Receptors 38"
# [1] "Potential Ligands 100"
# [1] "Top ranked ligands 3"
#
# [1] "Airway Epithelium --> B cells - Top ranked ligands: 3"
# [1] "Airway Epithelium --> B cells - Thereof upregulated: 0"
#
#
# [1] "Alveolar Epithelium --> B cells - Top ranked ligands: 3"
# [1] "Alveolar Epithelium --> B cells - Thereof upregulated: 1"
#
#
# [1] "capillary EC --> B cells - Top ranked ligands: 3"
# [1] "capillary EC --> B cells - Thereof upregulated: 1"
#
#
# [1] "vascular EC --> B cells - Top ranked ligands: 3"
# [1] "vascular EC --> B cells - Thereof upregulated: 1"
#
#
# [1] "lymphatic EC --> B cells - Top ranked ligands: 3"
# [1] "lymphatic EC --> B cells - Thereof upregulated: 0"
#
#
# [1] "Fibroblasts --> B cells - Top ranked ligands: 3"
# [1] "Fibroblasts --> B cells - Thereof upregulated: 0"
#
#
# [1] "SMC/Pericytes --> B cells - Top ranked ligands: 3"
# [1] "SMC/Pericytes --> B cells - Thereof upregulated: 0"
#
#
# [1] "Macrophages --> B cells - Top ranked ligands: 3"
# [1] "Macrophages --> B cells - Thereof upregulated: 0"
#
#
# [1] "DC --> B cells - Top ranked ligands: 3"
# [1] "DC --> B cells - Thereof upregulated: 0"
#
#
# [1] "Mast cells --> B cells - Top ranked ligands: 3"
# [1] "Mast cells --> B cells - Thereof upregulated: 1"
#
#
# [1] "B cells --> B cells - Top ranked ligands: 3"
# [1] "B cells --> B cells - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> B cells - Top ranked ligands: 3"
# [1] "Plasma cells --> B cells - Thereof upregulated: 0"
#
#
# [1] "T cells --> B cells - Top ranked ligands: 3"
# [1] "T cells --> B cells - Thereof upregulated: 0"
#
#
# [1] "NK cells --> B cells - Top ranked ligands: 3"
# [1] "NK cells --> B cells - Thereof upregulated: 0"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_B_cells.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_B_cells.csv"
# [1] "Plasma cells (FC vs. CC): Proceeding with geneset of interest of length: 1"
# [1] "Using 1 genes differently regulated genes in Plasma cells (Plasma cells (FC vs. CC))"
# [1] "Expressed Ligands 308"
# [1] "Expressed Receptors 43"
# [1] "Potential Ligands 89"
# [1] "Top ranked ligands 3"
#
# [1] "Airway Epithelium --> Plasma cells - Top ranked ligands: 3"
# [1] "Airway Epithelium --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "Alveolar Epithelium --> Plasma cells - Top ranked ligands: 3"
# [1] "Alveolar Epithelium --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "capillary EC --> Plasma cells - Top ranked ligands: 3"
# [1] "capillary EC --> Plasma cells - Thereof upregulated: 1"
#
#
# [1] "vascular EC --> Plasma cells - Top ranked ligands: 3"
# [1] "vascular EC --> Plasma cells - Thereof upregulated: 1"
#
#
# [1] "lymphatic EC --> Plasma cells - Top ranked ligands: 3"
# [1] "lymphatic EC --> Plasma cells - Thereof upregulated: 1"
#
#
# [1] "Fibroblasts --> Plasma cells - Top ranked ligands: 3"
# [1] "Fibroblasts --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "SMC/Pericytes --> Plasma cells - Top ranked ligands: 3"
# [1] "SMC/Pericytes --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "Macrophages --> Plasma cells - Top ranked ligands: 3"
# [1] "Macrophages --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "DC --> Plasma cells - Top ranked ligands: 3"
# [1] "DC --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "Mast cells --> Plasma cells - Top ranked ligands: 3"
# [1] "Mast cells --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "B cells --> Plasma cells - Top ranked ligands: 3"
# [1] "B cells --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> Plasma cells - Top ranked ligands: 3"
# [1] "Plasma cells --> Plasma cells - Thereof upregulated: 1"
#
#
# [1] "T cells --> Plasma cells - Top ranked ligands: 3"
# [1] "T cells --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "NK cells --> Plasma cells - Top ranked ligands: 3"
# [1] "NK cells --> Plasma cells - Thereof upregulated: 0"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_Plasma_cells.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_Plasma_cells.csv"
# [1] "T cells (FC vs. CC): Proceeding with geneset of interest of length: 85"
# [1] "Using 85 genes differently regulated genes in T cells (T cells (FC vs. CC))"
# [1] "Expressed Ligands 308"
# [1] "Expressed Receptors 41"
# [1] "Potential Ligands 109"
# [1] "Top ranked ligands 1"
#
# [1] "Airway Epithelium --> T cells - Top ranked ligands: 1"
# [1] "Airway Epithelium --> T cells - Thereof upregulated: 0"
#
#
# [1] "Alveolar Epithelium --> T cells - Top ranked ligands: 1"
# [1] "Alveolar Epithelium --> T cells - Thereof upregulated: 1"
#
#
# [1] "capillary EC --> T cells - Top ranked ligands: 1"
# [1] "capillary EC --> T cells - Thereof upregulated: 0"
#
#
# [1] "vascular EC --> T cells - Top ranked ligands: 1"
# [1] "vascular EC --> T cells - Thereof upregulated: 1"
#
#
# [1] "lymphatic EC --> T cells - Top ranked ligands: 1"
# [1] "lymphatic EC --> T cells - Thereof upregulated: 0"
#
#
# [1] "Fibroblasts --> T cells - Top ranked ligands: 1"
# [1] "Fibroblasts --> T cells - Thereof upregulated: 1"
#
#
# [1] "SMC/Pericytes --> T cells - Top ranked ligands: 1"
# [1] "SMC/Pericytes --> T cells - Thereof upregulated: 1"
#
#
# [1] "Macrophages --> T cells - Top ranked ligands: 1"
# [1] "Macrophages --> T cells - Thereof upregulated: 0"
#
#
# [1] "DC --> T cells - Top ranked ligands: 1"
# [1] "DC --> T cells - Thereof upregulated: 0"
#
#
# [1] "Mast cells --> T cells - Top ranked ligands: 1"
# [1] "Mast cells --> T cells - Thereof upregulated: 0"
#
#
# [1] "B cells --> T cells - Top ranked ligands: 1"
# [1] "B cells --> T cells - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> T cells - Top ranked ligands: 1"
# [1] "Plasma cells --> T cells - Thereof upregulated: 0"
#
#
# [1] "T cells --> T cells - Top ranked ligands: 1"
# [1] "T cells --> T cells - Thereof upregulated: 0"
#
#
# [1] "NK cells --> T cells - Top ranked ligands: 1"
# [1] "NK cells --> T cells - Thereof upregulated: 0"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_T_cells.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_T_cells.csv"
# [1] "NK cells (FC vs. CC): Proceeding with geneset of interest of length: 106"
# [1] "Using 106 genes differently regulated genes in NK cells (NK cells (FC vs. CC))"
# [1] "Expressed Ligands 308"
# [1] "Expressed Receptors 25"
# [1] "Potential Ligands 86"
# [1] "Top ranked ligands 57"
#
# [1] "Airway Epithelium --> NK cells - Top ranked ligands: 57"
# [1] "Airway Epithelium --> NK cells - Thereof upregulated: 10"
#
#
# [1] "Alveolar Epithelium --> NK cells - Top ranked ligands: 57"
# [1] "Alveolar Epithelium --> NK cells - Thereof upregulated: 8"
#
#
# [1] "capillary EC --> NK cells - Top ranked ligands: 57"
# [1] "capillary EC --> NK cells - Thereof upregulated: 10"
#
#
# [1] "vascular EC --> NK cells - Top ranked ligands: 57"
# [1] "vascular EC --> NK cells - Thereof upregulated: 18"
#
#
# [1] "lymphatic EC --> NK cells - Top ranked ligands: 57"
# [1] "lymphatic EC --> NK cells - Thereof upregulated: 4"
#
#
# [1] "Fibroblasts --> NK cells - Top ranked ligands: 57"
# [1] "Fibroblasts --> NK cells - Thereof upregulated: 14"
#
#
# [1] "SMC/Pericytes --> NK cells - Top ranked ligands: 57"
# [1] "SMC/Pericytes --> NK cells - Thereof upregulated: 11"
#
#
# [1] "Macrophages --> NK cells - Top ranked ligands: 57"
# [1] "Macrophages --> NK cells - Thereof upregulated: 15"
#
#
# [1] "DC --> NK cells - Top ranked ligands: 57"
# [1] "DC --> NK cells - Thereof upregulated: 2"
#
#
# [1] "Mast cells --> NK cells - Top ranked ligands: 57"
# [1] "Mast cells --> NK cells - Thereof upregulated: 4"
#
#
# [1] "B cells --> NK cells - Top ranked ligands: 57"
# [1] "B cells --> NK cells - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> NK cells - Top ranked ligands: 57"
# [1] "Plasma cells --> NK cells - Thereof upregulated: 1"
#
#
# [1] "T cells --> NK cells - Top ranked ligands: 57"
# [1] "T cells --> NK cells - Thereof upregulated: 2"
#
#
# [1] "NK cells --> NK cells - Top ranked ligands: 57"
# [1] "NK cells --> NK cells - Thereof upregulated: 3"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_NK_cells.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_exvivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_NK_cells.csv"

# %%
write.csv(quant_results_df, paste0(results_dir, '220207_quant_crosstalk_FC_CC.csv'))
quant_results_df
# Out:
#                     Airway Epithelium Alveolar Epithelium capillary EC
# Airway Epithelium   0                 27                  0
# Alveolar Epithelium 0                 39                  0
# capillary EC        0                 31                  0
# vascular EC         0                 56                  0
# lymphatic EC        0                 17                  0
# Fibroblasts         0                 47                  0
# SMC/Pericytes       0                 45                  0
# Macrophages         0                 37                  0
# DC                  0                  3                  0
# Mast cells          0                 10                  0
# B cells             0                  0                  0
# Plasma cells        0                  0                  0
# T cells             0                  7                  0
# NK cells            0                  6                  0
#                     vascular EC lymphatic EC Fibroblasts SMC/Pericytes
# Airway Epithelium   31          32           29          31
# Alveolar Epithelium 40          40           45          45
# capillary EC        28          27           33          33
# vascular EC         53          52           58          61
# lymphatic EC        14          15           17          17
# Fibroblasts         41          40           46          48
# SMC/Pericytes       42          40           46          49
# Macrophages         32          35           37          38
# DC                   5           5            4           4
# Mast cells          11           9           10          11
# B cells              0           0            0           0
# Plasma cells         2           1            1           2
# T cells              8           8            8           8
# NK cells             6           5            5           7
#                     Macrophages DC Mast cells B cells Plasma cells T cells
# Airway Epithelium   32          17 2          0       0            0
# Alveolar Epithelium 40          15 4          1       0            1
# capillary EC        27          14 3          1       1            0
# vascular EC         56          21 7          1       1            1
# lymphatic EC        20           6 3          0       1            0
# Fibroblasts         42          20 5          0       0            1
# SMC/Pericytes       46          16 7          0       0            1
# Macrophages         35          20 5          0       0            0
# DC                   4           2 1          0       0            0
# Mast cells          13           4 3          1       0            0
# B cells              0           0 0          0       0            0
# Plasma cells         2           0 0          0       1            0
# T cells              7           5 0          0       0            0
# NK cells             7           4 1          0       0            0
#                     NK cells
# Airway Epithelium   10
# Alveolar Epithelium  8
# capillary EC        10
# vascular EC         18
# lymphatic EC         4
# Fibroblasts         14
# SMC/Pericytes       11
# Macrophages         15
# DC                   2
# Mast cells           4
# B cells              0
# Plasma cells         1
# T cells              2
# NK cells             3

# %%
write.csv(qual_results_df, paste0(results_dir, '220207_qual_crosstalk_FC_CC.csv'))
qual_results_df
# Out:
#                     Airway Epithelium Alveolar Epithelium capillary EC
# Airway Epithelium   0                 1.0940329           0
# Alveolar Epithelium 0                 1.3927742           0
# capillary EC        0                 0.6062182           0
# vascular EC         0                 2.2383282           0
# lymphatic EC        0                 0.7822199           0
# Fibroblasts         0                 1.9839980           0
# SMC/Pericytes       0                 2.0398041           0
# Macrophages         0                 2.1302126           0
# DC                  0                 0.1720985           0
# Mast cells          0                 0.5598354           0
# B cells             0                 0.0000000           0
# Plasma cells        0                 0.0000000           0
# T cells             0                 0.1827085           0
# NK cells            0                 0.3448446           0
#                     vascular EC lymphatic EC Fibroblasts SMC/Pericytes
# Airway Epithelium   1.54659939  1.57506906   1.75838954  1.55431504
# Alveolar Epithelium 1.78199139  1.79875321   2.22525948  2.15323493
# capillary EC        0.57687320  0.54492704   0.73866150  0.73994891
# vascular EC         2.56103671  2.47762538   2.99987014  2.96583388
# lymphatic EC        0.67924936  0.97863685   0.99081639  0.92651700
# Fibroblasts         1.94843079  1.86112678   2.61101810  2.48016030
# SMC/Pericytes       2.55286356  2.14715956   2.68736028  2.74523757
# Macrophages         1.81219163  2.27793164   2.93430422  2.71992210
# DC                  0.35298087  0.35334218   0.25707568  0.23542371
# Mast cells          0.75217241  0.55389778   0.77438040  0.79974774
# B cells             0.00000000  0.00000000   0.00000000  0.00000000
# Plasma cells        0.03387372  0.02326974   0.02108412  0.02983838
# T cells             0.20281784  0.22824768   0.25958090  0.23110593
# NK cells            0.39052733  0.37891108   0.45654446  0.48818640
#                     Macrophages DC         Mast cells B cells     Plasma cells
# Airway Epithelium   1.45757675  0.55545661 0.05736601 0.000000000 0.00000000
# Alveolar Epithelium 1.59685289  0.35091449 0.11444368 0.020813147 0.00000000
# capillary EC        0.63429980  0.17585428 0.09209890 0.043404059 0.05923539
# vascular EC         2.68894870  0.48151332 0.31784705 0.092224931 0.15456168
# lymphatic EC        1.19125584  0.21323504 0.09890368 0.000000000 0.07524307
# Fibroblasts         1.94427959  0.61704524 0.15883907 0.000000000 0.00000000
# SMC/Pericytes       2.46839224  0.44751311 0.14518190 0.000000000 0.00000000
# Macrophages         2.45086681  0.82742580 0.18513000 0.000000000 0.00000000
# DC                  0.24609477  0.15437238 0.02224709 0.000000000 0.00000000
# Mast cells          0.83083220  0.21914031 0.13176480 0.009668685 0.00000000
# B cells             0.00000000  0.00000000 0.00000000 0.000000000 0.00000000
# Plasma cells        0.02576392  0.00000000 0.00000000 0.000000000 0.01198401
# T cells             0.21126026  0.05918437 0.00000000 0.000000000 0.00000000
# NK cells            0.46303521  0.16092660 0.07166797 0.000000000 0.00000000
#                     T cells    NK cells
# Airway Epithelium   0.00000000 0.379090823
# Alveolar Epithelium 0.01754660 0.308706655
# capillary EC        0.00000000 0.148032441
# vascular EC         0.06120471 0.685711307
# lymphatic EC        0.00000000 0.178940469
# Fibroblasts         0.01001364 0.306704695
# SMC/Pericytes       0.01394310 0.348199149
# Macrophages         0.00000000 0.589845572
# DC                  0.00000000 0.099146023
# Mast cells          0.00000000 0.118042847
# B cells             0.00000000 0.000000000
# Plasma cells        0.00000000 0.007728891
# T cells             0.00000000 0.016145596
# NK cells            0.00000000 0.106826137
