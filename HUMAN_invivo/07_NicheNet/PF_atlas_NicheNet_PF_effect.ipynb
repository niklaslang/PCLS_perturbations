# %% [markdown]
# ## Human PCLS: cellular crosstalk with NicheNetNiklas after Fibrotic Cocktail

# %%
suppressPackageStartupMessages(library(nichenetr))
suppressPackageStartupMessages(library(Seurat))
suppressPackageStartupMessages(library(tidyverse))
suppressPackageStartupMessages(library(patchwork))
suppressPackageStartupMessages(library(data.table))
suppressPackageStartupMessages(library(Matrix))
suppressPackageStartupMessages(library(igraph))
suppressPackageStartupMessages(library(gridExtra))
suppressPackageStartupMessages(library(viridis))

# %%
## set working directory
setwd('/home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/02_figures/NicheNet/')

# %% [markdown]
# ### Path to required input data

# %%
dge_dir = '/home/niklas/projects/niche_environments_FIBROSIS/IPF_cell_atlas_reference_CPC/01_data/DGE_IPF_vs_healthy/'
table_dir = '/home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_inputs/'
results_dir = '/home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/'

# %% [markdown]
# ### Load NicheNet models and networks

# %%
## load NicheNet models and networks ##
ligand_target_matrix <- readRDS('/home/niklas/data/nichenet_models/ligand_target_matrix_HUMAN.rds')
lr_network <- readRDS('/home/niklas/data/nichenet_models/ligand_receptor_network_HUMAN.rds')
weighted_networks_lr <- readRDS('/home/niklas/data/nichenet_models/weighted_ligand_receptor_network_HUMAN.rds')

# %% [markdown]
# ### Function to perform NicheNet Ligand activity analysis

# %%
## function to perform ligand activity analysis ##
ligand_activity_analysis <- function(sender_ct, receiver_ct, geneset_oi, 
                            geneset_title,
                            pct_expr_table, pct_thresh = 0.05,
                            pearson_thresh = 0.08){
    
    
    ## retrieve genes expressed by receiver
    expr_genes_receiver = rownames(pct_expr_table[pct_expr_table[, receiver_ct] > pct_thresh, ])
    background_expr_genes = expr_genes_receiver %>% .[. %in% rownames(ligand_target_matrix)]
    
    ## retrieve genes expressed by sender
    list_expr_genes_sender = lapply(sender_ct, function(x){rownames(pct_expr_table[pct_expr_table[, x] > pct_thresh, ])})
    expr_genes_sender = list_expr_genes_sender %>% unlist() %>% unique()
    
    ## status message ##
    print(paste0("Using ", length(geneset_oi), " genes differently regulated genes in ", receiver_ct, " (",
                 geneset_title, ")"))
    
    ### STEP1: Ligand activity analysis ###
    ## Define a set of potential ligands and receptors 
    # retrieve ligands and receptors
    ligands = lr_network %>% pull(from) %>% unique()
    receptors = lr_network %>% pull(to) %>% unique()
    # ligands expressed by sender celltypes
    expr_ligands = intersect(ligands, expr_genes_sender) 
    # receptor expressed by receiver celltypes
    expr_receptors = intersect(receptors, expr_genes_receiver)
    ### status messages ###
    print(paste0("Expressed Ligands ", length(expr_ligands)))
    print(paste0("Expressed Receptors ", length(expr_receptors)))
    
    ## filter ligands
    # only consider ligands with matching receptors (according to NicheNets databases)
    potential_ligands = lr_network %>% filter(from %in% expr_ligands & to %in% expr_receptors) %>%
                        pull(from) %>% unique()
    ### status message ###
    print(paste0("Potential Ligands ", length(potential_ligands)))
    
    ## predict ligand activities
    ligand_activities = predict_ligand_activities(geneset = geneset_oi,
                                                  background_expressed_genes = background_expr_genes,
                                                  ligand_target_matrix = ligand_target_matrix,
                                                  potential_ligands = potential_ligands)

    ## rank ligands by pearson correlation coefficient
    ligand_activities = ligand_activities %>% arrange(-pearson) %>% mutate(rank = rank(desc(pearson)))
    
    # filter consider ligands with pearson's correlation >= pearson_tresh
    ligand_activities = ligand_activities %>% filter(pearson >= pearson_thresh)
    
    ### status message ###
    print(paste0("Top ranked ligands ", length(ligand_activities$test_ligand)))
    
    return(ligand_activities)  
}

# %%
target_gene_prediction <- function(best_upstream_ligands,geneset_oi, target_thresh = 0.33, n_targets = 500){
    
    ## identify ligand targets
    active_ligand_target_links_df = best_upstream_ligands %>% 
                                    lapply(get_weighted_ligand_target_links,geneset = geneset_oi, ligand_target_matrix = ligand_target_matrix, n = n_targets) %>% bind_rows() %>% drop_na()
    active_ligand_target_links = prepare_ligand_target_visualization(ligand_target_df = active_ligand_target_links_df, ligand_target_matrix = ligand_target_matrix, cutoff = target_thresh)
    
    ## reformat data
    order_ligands = intersect(best_upstream_ligands, colnames(active_ligand_target_links)) %>% rev() %>% make.names()
    order_targets = active_ligand_target_links_df$target %>% unique() %>% 
                    intersect(rownames(active_ligand_target_links)) %>% make.names()
    rownames(active_ligand_target_links) = rownames(active_ligand_target_links) %>% make.names() 
    colnames(active_ligand_target_links) = colnames(active_ligand_target_links) %>% make.names() # make.names() for heatmap visualization of genes like H2-T23
    
    ## final ligand-target heatmap
    vis_ligand_target = active_ligand_target_links[order_targets,order_ligands] %>% t()
    
    ## output: ligand-target matrix
    return(vis_ligand_target) 
    
}

# %% [markdown]
# ### Run NicheNet iteratively to detect crosstalk between all cells for FC vs CC

# %%
## read avg expression table
avg_expr <- read.csv(paste0(table_dir, '220207_IPF_atlas_invivo_healthy_avg_expr_SCALED.csv'), row.names = 1, check.names = F, header = T)
pct_expr <- read.csv(paste0(table_dir, '220207_IPF_atlas_invivo_healthy_pct_expr.csv'), row.names = 1, check.names = F, header = T)

# %%
cell_type_names <- c('Airway Epithelium','Alveolar Epithelium',
                      'capillary EC', 'vascular EC', 'lymphatic EC',
                      'Fibroblasts','SMC/Pericytes',
                      'Monocytes','Macrophages','DC','Mast cells',
                      'B cells','Plasma cells','T cells','NK cells')
cell_type_labels <- c('Airway_Epithelium','Alveolar_Epithelium',
                      'capillary_EC', 'vascular_EC', 'lymphatic_EC',
                      'Fibroblasts','SMC_Pericytes',
                      'Monocytes','Macrophages','DC','Mast_cells',
                      'B_cells','Plasma_cells','T_cells','NK_cells')

# %%
## create final results matrix
quant_results_df <- data.frame(matrix(ncol = length(cell_type_names), nrow = length(cell_type_names)))
colnames(quant_results_df) <- cell_type_names # RECEIVER (!!!)
rownames(quant_results_df) <- cell_type_names # SENDER (!!!)
quant_results_df
# Out:
#                     Airway Epithelium Alveolar Epithelium capillary EC
# Airway Epithelium   NA                NA                  NA
# Alveolar Epithelium NA                NA                  NA
# capillary EC        NA                NA                  NA
# vascular EC         NA                NA                  NA
# lymphatic EC        NA                NA                  NA
# Fibroblasts         NA                NA                  NA
# SMC/Pericytes       NA                NA                  NA
# Monocytes           NA                NA                  NA
# Macrophages         NA                NA                  NA
# DC                  NA                NA                  NA
# Mast cells          NA                NA                  NA
# B cells             NA                NA                  NA
# Plasma cells        NA                NA                  NA
# T cells             NA                NA                  NA
# NK cells            NA                NA                  NA
#                     vascular EC lymphatic EC Fibroblasts SMC/Pericytes
# Airway Epithelium   NA          NA           NA          NA
# Alveolar Epithelium NA          NA           NA          NA
# capillary EC        NA          NA           NA          NA
# vascular EC         NA          NA           NA          NA
# lymphatic EC        NA          NA           NA          NA
# Fibroblasts         NA          NA           NA          NA
# SMC/Pericytes       NA          NA           NA          NA
# Monocytes           NA          NA           NA          NA
# Macrophages         NA          NA           NA          NA
# DC                  NA          NA           NA          NA
# Mast cells          NA          NA           NA          NA
# B cells             NA          NA           NA          NA
# Plasma cells        NA          NA           NA          NA
# T cells             NA          NA           NA          NA
# NK cells            NA          NA           NA          NA
#                     Monocytes Macrophages DC Mast cells B cells Plasma cells
# Airway Epithelium   NA        NA          NA NA         NA      NA
# Alveolar Epithelium NA        NA          NA NA         NA      NA
# capillary EC        NA        NA          NA NA         NA      NA
# vascular EC         NA        NA          NA NA         NA      NA
# lymphatic EC        NA        NA          NA NA         NA      NA
# Fibroblasts         NA        NA          NA NA         NA      NA
# SMC/Pericytes       NA        NA          NA NA         NA      NA
# Monocytes           NA        NA          NA NA         NA      NA
# Macrophages         NA        NA          NA NA         NA      NA
# DC                  NA        NA          NA NA         NA      NA
# Mast cells          NA        NA          NA NA         NA      NA
# B cells             NA        NA          NA NA         NA      NA
# Plasma cells        NA        NA          NA NA         NA      NA
# T cells             NA        NA          NA NA         NA      NA
# NK cells            NA        NA          NA NA         NA      NA
#                     T cells NK cells
# Airway Epithelium   NA      NA
# Alveolar Epithelium NA      NA
# capillary EC        NA      NA
# vascular EC         NA      NA
# lymphatic EC        NA      NA
# Fibroblasts         NA      NA
# SMC/Pericytes       NA      NA
# Monocytes           NA      NA
# Macrophages         NA      NA
# DC                  NA      NA
# Mast cells          NA      NA
# B cells             NA      NA
# Plasma cells        NA      NA
# T cells             NA      NA
# NK cells            NA      NA

# %%
qual_results_df <- copy(quant_results_df)
qual_results_df
# Out:
#                     Airway Epithelium Alveolar Epithelium capillary EC
# Airway Epithelium   NA                NA                  NA
# Alveolar Epithelium NA                NA                  NA
# capillary EC        NA                NA                  NA
# vascular EC         NA                NA                  NA
# lymphatic EC        NA                NA                  NA
# Fibroblasts         NA                NA                  NA
# SMC/Pericytes       NA                NA                  NA
# Monocytes           NA                NA                  NA
# Macrophages         NA                NA                  NA
# DC                  NA                NA                  NA
# Mast cells          NA                NA                  NA
# B cells             NA                NA                  NA
# Plasma cells        NA                NA                  NA
# T cells             NA                NA                  NA
# NK cells            NA                NA                  NA
#                     vascular EC lymphatic EC Fibroblasts SMC/Pericytes
# Airway Epithelium   NA          NA           NA          NA
# Alveolar Epithelium NA          NA           NA          NA
# capillary EC        NA          NA           NA          NA
# vascular EC         NA          NA           NA          NA
# lymphatic EC        NA          NA           NA          NA
# Fibroblasts         NA          NA           NA          NA
# SMC/Pericytes       NA          NA           NA          NA
# Monocytes           NA          NA           NA          NA
# Macrophages         NA          NA           NA          NA
# DC                  NA          NA           NA          NA
# Mast cells          NA          NA           NA          NA
# B cells             NA          NA           NA          NA
# Plasma cells        NA          NA           NA          NA
# T cells             NA          NA           NA          NA
# NK cells            NA          NA           NA          NA
#                     Monocytes Macrophages DC Mast cells B cells Plasma cells
# Airway Epithelium   NA        NA          NA NA         NA      NA
# Alveolar Epithelium NA        NA          NA NA         NA      NA
# capillary EC        NA        NA          NA NA         NA      NA
# vascular EC         NA        NA          NA NA         NA      NA
# lymphatic EC        NA        NA          NA NA         NA      NA
# Fibroblasts         NA        NA          NA NA         NA      NA
# SMC/Pericytes       NA        NA          NA NA         NA      NA
# Monocytes           NA        NA          NA NA         NA      NA
# Macrophages         NA        NA          NA NA         NA      NA
# DC                  NA        NA          NA NA         NA      NA
# Mast cells          NA        NA          NA NA         NA      NA
# B cells             NA        NA          NA NA         NA      NA
# Plasma cells        NA        NA          NA NA         NA      NA
# T cells             NA        NA          NA NA         NA      NA
# NK cells            NA        NA          NA NA         NA      NA
#                     T cells NK cells
# Airway Epithelium   NA      NA
# Alveolar Epithelium NA      NA
# capillary EC        NA      NA
# vascular EC         NA      NA
# lymphatic EC        NA      NA
# Fibroblasts         NA      NA
# SMC/Pericytes       NA      NA
# Monocytes           NA      NA
# Macrophages         NA      NA
# DC                  NA      NA
# Mast cells          NA      NA
# B cells             NA      NA
# Plasma cells        NA      NA
# T cells             NA      NA
# NK cells            NA      NA

# %% [markdown]
# ### Run NicheNet

# %%
for(i in 1:length(cell_type_names)){
    
    ## step 1: define RECEIVER and SENDER cells
    all_senders <- cell_type_names
    all_sender_labels <- cell_type_labels
    receiver_ct <- cell_type_names[i]
    receiver_labels <- cell_type_labels[i]
    
    ## step 2: define geneset of interest
    # read dge table
    dge_table <- read.csv(paste0(dge_dir, '210616_CPC_IPF_reference_DGE_IPF_vs_healthy_' , cell_type_labels[i], '.csv'))
    # only significant genes: pval_adj < 0.05
    dge_table = dge_table %>% filter(qval < 0.05)
    # only genes expressed in at least 10% per group
    dge_table = dge_table %>% filter(pct.healthy > 0.1)
    dge_table = dge_table %>% filter(pct.ILD > 0.1)
    # only upregulated genes with log2fc > 0.25
    dge_genes_up = dge_table %>% filter(log2fc > 0.25)
    geneset_oi <- dge_genes_up$gene
    geneset_title <- paste0(cell_type_names[i], ' (IPF vs. healthy)')
    print(paste0(cell_type_names[i], ' (IPF vs. healthy): Proceeding with geneset of interest of length: ', length(geneset_oi)))
    
    ## step 3: run ligand activity analysis
    top_ligands_table <- ligand_activity_analysis(all_senders, receiver_ct, geneset_oi = geneset_oi,
                                           geneset_title = geneset_title, pct_thresh = 0.05,
                                           pct_expr_table = pct_expr, pearson_thresh = 0.05)
    
    ## dissect crosstalk between all pairs of cell types quantitatively and qualitatively
    
    # for each sender cell type check which top ligands are upregulated
    for(i in 1:length(all_senders)){
        sender_ct <- all_senders[i]
        sender_label <- all_sender_labels[i]
        # read respective DGE table
        # read dge table
        dge_table <- read.csv(paste0(dge_dir, '210616_CPC_IPF_reference_DGE_IPF_vs_healthy_' , sender_label, '.csv'))
        
        # subset DGE table to top ligands
        ligands_dge = dge_table %>% filter(gene %in% top_ligands_table$test_ligand) 
        
        # filter DGE table by logFC and q-Value
        # if logFC > 0.25 and q-Value < 0.05, a ligand is upregulated
        ligands_dge = ligands_dge %>% filter(qval < 0.05)
        ligands_dge = ligands_dge %>% filter(log2fc > 0.25)
        
        ## add info whether gene is upregulated in SENDER cell type to ligand activity table
        top_ligands_table <- top_ligands_table %>% mutate(new_col = case_when(test_ligand %in% ligands_dge$gene ~ 1,
                                         !(test_ligand %in% ligands_dge$gene) ~ 0))
        colnames(top_ligands_table)[colnames(top_ligands_table) == 'new_col'] <- paste0(sender_label, '_UP')
        
        ### quantitative approach ### 
        # count genes in resulting DGE table --> no. of upregulated top ligands
        ct_quant_score <- length(ligands_dge$gene)
        cat('\n')
        print(paste0(sender_ct, ' --> ', receiver_ct, ' - Top ranked ligands: ', length(top_ligands_table$test_ligand)))
        print(paste0(sender_ct, ' --> ', receiver_ct, ' - Thereof upregulated: ', ct_quant_score))
        cat('\n')
        # fill final results matrix
        quant_results_df[sender_ct, receiver_ct] <- ct_quant_score
        
        ### qualitative approach ### 
        
        # filter ligands results table: upregulated ligands only
        ligands_up = top_ligands_table %>% filter(test_ligand %in% ligands_dge$gene)
        
        # filter avg expression table: only sender cell type
        ligands_avg_expr = avg_expr %>% select(sender_ct)
        # filter avg expression table: only top ligands
        ligands_avg_expr = ligands_avg_expr %>% filter(rownames(ligands_avg_expr) %in% ligands_dge$gene)
        ligands_avg_expr$gene <- rownames(ligands_avg_expr)
        rownames(ligands_avg_expr) <- NULL
        
        # merge ligands results table with ligands avg expression table
        ligands_up <- merge.data.frame(x = ligands_up, y = ligands_avg_expr, by.x = 'test_ligand', by.y = 'gene')
        
        # add new colum to ligand results table: avg expression * ligand score (pearsons rho)
        ligands_up$contribution <- ligands_up[, sender_ct] * ligands_up$pearson
        # sender celltype contribution score equals the sum of the new column
        ct_qual_score <- sum(ligands_up$contribution)
        
        # fill final results matrix
        qual_results_df[sender_ct, receiver_ct] <- ct_qual_score

    }
    
    ## save ligand activity analysis
    print(paste0('Writing ligand activity table to:  ', results_dir, 'nichenet_ligand_act_', receiver_labels, '.csv'))
    write.csv(top_ligands_table, paste0(results_dir, 'nichenet_ligand_act_', receiver_labels, '.csv'))
    
    ## step 4: target gene prediction
    ligand_target_prediction <- target_gene_prediction(best_upstream_ligands = top_ligands_table$test_ligand, geneset_oi = geneset_oi)
    print(paste0('Writing ligand target matrix table to:  ', results_dir, 'nichenet_ligand_target_matrix_', receiver_labels, '.csv'))
    write.csv(ligand_target_prediction, paste0(results_dir, 'nichenet_ligand_target_matrix_', receiver_labels, '.csv'))
}
# Out:
# [1] "Airway Epithelium (IPF vs. healthy): Proceeding with geneset of interest of length: 504"
# [1] "Using 504 genes differently regulated genes in Airway Epithelium (Airway Epithelium (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 168"
# [1] "Potential Ligands 253"
# [1] "Top ranked ligands 0"
#
# [1] "Airway Epithelium --> Airway Epithelium - Top ranked ligands: 0"
# [1] "Airway Epithelium --> Airway Epithelium - Thereof upregulated: 0"
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(sender_ct)` instead of `sender_ct` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
# [1] "Alveolar Epithelium --> Airway Epithelium - Top ranked ligands: 0"
# [1] "Alveolar Epithelium --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "capillary EC --> Airway Epithelium - Top ranked ligands: 0"
# [1] "capillary EC --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "vascular EC --> Airway Epithelium - Top ranked ligands: 0"
# [1] "vascular EC --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "lymphatic EC --> Airway Epithelium - Top ranked ligands: 0"
# [1] "lymphatic EC --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "Fibroblasts --> Airway Epithelium - Top ranked ligands: 0"
# [1] "Fibroblasts --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "SMC/Pericytes --> Airway Epithelium - Top ranked ligands: 0"
# [1] "SMC/Pericytes --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "Monocytes --> Airway Epithelium - Top ranked ligands: 0"
# [1] "Monocytes --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "Macrophages --> Airway Epithelium - Top ranked ligands: 0"
# [1] "Macrophages --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "DC --> Airway Epithelium - Top ranked ligands: 0"
# [1] "DC --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "Mast cells --> Airway Epithelium - Top ranked ligands: 0"
# [1] "Mast cells --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "B cells --> Airway Epithelium - Top ranked ligands: 0"
# [1] "B cells --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> Airway Epithelium - Top ranked ligands: 0"
# [1] "Plasma cells --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "T cells --> Airway Epithelium - Top ranked ligands: 0"
# [1] "T cells --> Airway Epithelium - Thereof upregulated: 0"
#
#
# [1] "NK cells --> Airway Epithelium - Top ranked ligands: 0"
# [1] "NK cells --> Airway Epithelium - Thereof upregulated: 0"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_Airway_Epithelium.csv"
# Warning message:
# “Unknown or uninitialised column: `weight`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# Warning message:
# “Unknown or uninitialised column: `ligand`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# Warning message:
# “Unknown or uninitialised column: `ligand`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# Warning message:
# “Unknown or uninitialised column: `ligand`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_Airway_Epithelium.csv"
# [1] "Alveolar Epithelium (IPF vs. healthy): Proceeding with geneset of interest of length: 1081"
# [1] "Using 1081 genes differently regulated genes in Alveolar Epithelium (Alveolar Epithelium (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 152"
# [1] "Potential Ligands 247"
# [1] "Top ranked ligands 239"
#
# [1] "Airway Epithelium --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "Airway Epithelium --> Alveolar Epithelium - Thereof upregulated: 21"
#
#
# [1] "Alveolar Epithelium --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "Alveolar Epithelium --> Alveolar Epithelium - Thereof upregulated: 50"
#
#
# [1] "capillary EC --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "capillary EC --> Alveolar Epithelium - Thereof upregulated: 41"
#
#
# [1] "vascular EC --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "vascular EC --> Alveolar Epithelium - Thereof upregulated: 27"
#
#
# [1] "lymphatic EC --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "lymphatic EC --> Alveolar Epithelium - Thereof upregulated: 15"
#
#
# [1] "Fibroblasts --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "Fibroblasts --> Alveolar Epithelium - Thereof upregulated: 61"
#
#
# [1] "SMC/Pericytes --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "SMC/Pericytes --> Alveolar Epithelium - Thereof upregulated: 50"
#
#
# [1] "Monocytes --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "Monocytes --> Alveolar Epithelium - Thereof upregulated: 17"
#
#
# [1] "Macrophages --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "Macrophages --> Alveolar Epithelium - Thereof upregulated: 22"
#
#
# [1] "DC --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "DC --> Alveolar Epithelium - Thereof upregulated: 23"
#
#
# [1] "Mast cells --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "Mast cells --> Alveolar Epithelium - Thereof upregulated: 23"
#
#
# [1] "B cells --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "B cells --> Alveolar Epithelium - Thereof upregulated: 14"
#
#
# [1] "Plasma cells --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "Plasma cells --> Alveolar Epithelium - Thereof upregulated: 7"
#
#
# [1] "T cells --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "T cells --> Alveolar Epithelium - Thereof upregulated: 9"
#
#
# [1] "NK cells --> Alveolar Epithelium - Top ranked ligands: 239"
# [1] "NK cells --> Alveolar Epithelium - Thereof upregulated: 14"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_Alveolar_Epithelium.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_Alveolar_Epithelium.csv"
# [1] "capillary EC (IPF vs. healthy): Proceeding with geneset of interest of length: 474"
# [1] "Using 474 genes differently regulated genes in capillary EC (capillary EC (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 124"
# [1] "Potential Ligands 225"
# [1] "Top ranked ligands 220"
#
# [1] "Airway Epithelium --> capillary EC - Top ranked ligands: 220"
# [1] "Airway Epithelium --> capillary EC - Thereof upregulated: 18"
#
#
# [1] "Alveolar Epithelium --> capillary EC - Top ranked ligands: 220"
# [1] "Alveolar Epithelium --> capillary EC - Thereof upregulated: 46"
#
#
# [1] "capillary EC --> capillary EC - Top ranked ligands: 220"
# [1] "capillary EC --> capillary EC - Thereof upregulated: 38"
#
#
# [1] "vascular EC --> capillary EC - Top ranked ligands: 220"
# [1] "vascular EC --> capillary EC - Thereof upregulated: 24"
#
#
# [1] "lymphatic EC --> capillary EC - Top ranked ligands: 220"
# [1] "lymphatic EC --> capillary EC - Thereof upregulated: 14"
#
#
# [1] "Fibroblasts --> capillary EC - Top ranked ligands: 220"
# [1] "Fibroblasts --> capillary EC - Thereof upregulated: 55"
#
#
# [1] "SMC/Pericytes --> capillary EC - Top ranked ligands: 220"
# [1] "SMC/Pericytes --> capillary EC - Thereof upregulated: 49"
#
#
# [1] "Monocytes --> capillary EC - Top ranked ligands: 220"
# [1] "Monocytes --> capillary EC - Thereof upregulated: 15"
#
#
# [1] "Macrophages --> capillary EC - Top ranked ligands: 220"
# [1] "Macrophages --> capillary EC - Thereof upregulated: 22"
#
#
# [1] "DC --> capillary EC - Top ranked ligands: 220"
# [1] "DC --> capillary EC - Thereof upregulated: 21"
#
#
# [1] "Mast cells --> capillary EC - Top ranked ligands: 220"
# [1] "Mast cells --> capillary EC - Thereof upregulated: 19"
#
#
# [1] "B cells --> capillary EC - Top ranked ligands: 220"
# [1] "B cells --> capillary EC - Thereof upregulated: 12"
#
#
# [1] "Plasma cells --> capillary EC - Top ranked ligands: 220"
# [1] "Plasma cells --> capillary EC - Thereof upregulated: 6"
#
#
# [1] "T cells --> capillary EC - Top ranked ligands: 220"
# [1] "T cells --> capillary EC - Thereof upregulated: 7"
#
#
# [1] "NK cells --> capillary EC - Top ranked ligands: 220"
# [1] "NK cells --> capillary EC - Thereof upregulated: 11"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_capillary_EC.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_capillary_EC.csv"
# [1] "vascular EC (IPF vs. healthy): Proceeding with geneset of interest of length: 485"
# [1] "Using 485 genes differently regulated genes in vascular EC (vascular EC (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 176"
# [1] "Potential Ligands 253"
# [1] "Top ranked ligands 226"
#
# [1] "Airway Epithelium --> vascular EC - Top ranked ligands: 226"
# [1] "Airway Epithelium --> vascular EC - Thereof upregulated: 20"
#
#
# [1] "Alveolar Epithelium --> vascular EC - Top ranked ligands: 226"
# [1] "Alveolar Epithelium --> vascular EC - Thereof upregulated: 51"
#
#
# [1] "capillary EC --> vascular EC - Top ranked ligands: 226"
# [1] "capillary EC --> vascular EC - Thereof upregulated: 40"
#
#
# [1] "vascular EC --> vascular EC - Top ranked ligands: 226"
# [1] "vascular EC --> vascular EC - Thereof upregulated: 26"
#
#
# [1] "lymphatic EC --> vascular EC - Top ranked ligands: 226"
# [1] "lymphatic EC --> vascular EC - Thereof upregulated: 15"
#
#
# [1] "Fibroblasts --> vascular EC - Top ranked ligands: 226"
# [1] "Fibroblasts --> vascular EC - Thereof upregulated: 57"
#
#
# [1] "SMC/Pericytes --> vascular EC - Top ranked ligands: 226"
# [1] "SMC/Pericytes --> vascular EC - Thereof upregulated: 47"
#
#
# [1] "Monocytes --> vascular EC - Top ranked ligands: 226"
# [1] "Monocytes --> vascular EC - Thereof upregulated: 17"
#
#
# [1] "Macrophages --> vascular EC - Top ranked ligands: 226"
# [1] "Macrophages --> vascular EC - Thereof upregulated: 22"
#
#
# [1] "DC --> vascular EC - Top ranked ligands: 226"
# [1] "DC --> vascular EC - Thereof upregulated: 20"
#
#
# [1] "Mast cells --> vascular EC - Top ranked ligands: 226"
# [1] "Mast cells --> vascular EC - Thereof upregulated: 26"
#
#
# [1] "B cells --> vascular EC - Top ranked ligands: 226"
# [1] "B cells --> vascular EC - Thereof upregulated: 13"
#
#
# [1] "Plasma cells --> vascular EC - Top ranked ligands: 226"
# [1] "Plasma cells --> vascular EC - Thereof upregulated: 6"
#
#
# [1] "T cells --> vascular EC - Top ranked ligands: 226"
# [1] "T cells --> vascular EC - Thereof upregulated: 8"
#
#
# [1] "NK cells --> vascular EC - Top ranked ligands: 226"
# [1] "NK cells --> vascular EC - Thereof upregulated: 11"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_vascular_EC.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_vascular_EC.csv"
# [1] "lymphatic EC (IPF vs. healthy): Proceeding with geneset of interest of length: 331"
# [1] "Using 331 genes differently regulated genes in lymphatic EC (lymphatic EC (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 150"
# [1] "Potential Ligands 235"
# [1] "Top ranked ligands 1"
#
# [1] "Airway Epithelium --> lymphatic EC - Top ranked ligands: 1"
# [1] "Airway Epithelium --> lymphatic EC - Thereof upregulated: 0"
#
#
# [1] "Alveolar Epithelium --> lymphatic EC - Top ranked ligands: 1"
# [1] "Alveolar Epithelium --> lymphatic EC - Thereof upregulated: 0"
#
#
# [1] "capillary EC --> lymphatic EC - Top ranked ligands: 1"
# [1] "capillary EC --> lymphatic EC - Thereof upregulated: 0"
#
#
# [1] "vascular EC --> lymphatic EC - Top ranked ligands: 1"
# [1] "vascular EC --> lymphatic EC - Thereof upregulated: 0"
#
#
# [1] "lymphatic EC --> lymphatic EC - Top ranked ligands: 1"
# [1] "lymphatic EC --> lymphatic EC - Thereof upregulated: 0"
#
#
# [1] "Fibroblasts --> lymphatic EC - Top ranked ligands: 1"
# [1] "Fibroblasts --> lymphatic EC - Thereof upregulated: 1"
#
#
# [1] "SMC/Pericytes --> lymphatic EC - Top ranked ligands: 1"
# [1] "SMC/Pericytes --> lymphatic EC - Thereof upregulated: 0"
#
#
# [1] "Monocytes --> lymphatic EC - Top ranked ligands: 1"
# [1] "Monocytes --> lymphatic EC - Thereof upregulated: 0"
#
#
# [1] "Macrophages --> lymphatic EC - Top ranked ligands: 1"
# [1] "Macrophages --> lymphatic EC - Thereof upregulated: 0"
#
#
# [1] "DC --> lymphatic EC - Top ranked ligands: 1"
# [1] "DC --> lymphatic EC - Thereof upregulated: 0"
#
#
# [1] "Mast cells --> lymphatic EC - Top ranked ligands: 1"
# [1] "Mast cells --> lymphatic EC - Thereof upregulated: 0"
#
#
# [1] "B cells --> lymphatic EC - Top ranked ligands: 1"
# [1] "B cells --> lymphatic EC - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> lymphatic EC - Top ranked ligands: 1"
# [1] "Plasma cells --> lymphatic EC - Thereof upregulated: 0"
#
#
# [1] "T cells --> lymphatic EC - Top ranked ligands: 1"
# [1] "T cells --> lymphatic EC - Thereof upregulated: 0"
#
#
# [1] "NK cells --> lymphatic EC - Top ranked ligands: 1"
# [1] "NK cells --> lymphatic EC - Thereof upregulated: 0"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_lymphatic_EC.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_lymphatic_EC.csv"
# [1] "Fibroblasts (IPF vs. healthy): Proceeding with geneset of interest of length: 973"
# [1] "Using 973 genes differently regulated genes in Fibroblasts (Fibroblasts (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 169"
# [1] "Potential Ligands 263"
# [1] "Top ranked ligands 249"
#
# [1] "Airway Epithelium --> Fibroblasts - Top ranked ligands: 249"
# [1] "Airway Epithelium --> Fibroblasts - Thereof upregulated: 25"
#
#
# [1] "Alveolar Epithelium --> Fibroblasts - Top ranked ligands: 249"
# [1] "Alveolar Epithelium --> Fibroblasts - Thereof upregulated: 56"
#
#
# [1] "capillary EC --> Fibroblasts - Top ranked ligands: 249"
# [1] "capillary EC --> Fibroblasts - Thereof upregulated: 46"
#
#
# [1] "vascular EC --> Fibroblasts - Top ranked ligands: 249"
# [1] "vascular EC --> Fibroblasts - Thereof upregulated: 29"
#
#
# [1] "lymphatic EC --> Fibroblasts - Top ranked ligands: 249"
# [1] "lymphatic EC --> Fibroblasts - Thereof upregulated: 15"
#
#
# [1] "Fibroblasts --> Fibroblasts - Top ranked ligands: 249"
# [1] "Fibroblasts --> Fibroblasts - Thereof upregulated: 67"
#
#
# [1] "SMC/Pericytes --> Fibroblasts - Top ranked ligands: 249"
# [1] "SMC/Pericytes --> Fibroblasts - Thereof upregulated: 53"
#
#
# [1] "Monocytes --> Fibroblasts - Top ranked ligands: 249"
# [1] "Monocytes --> Fibroblasts - Thereof upregulated: 17"
#
#
# [1] "Macrophages --> Fibroblasts - Top ranked ligands: 249"
# [1] "Macrophages --> Fibroblasts - Thereof upregulated: 25"
#
#
# [1] "DC --> Fibroblasts - Top ranked ligands: 249"
# [1] "DC --> Fibroblasts - Thereof upregulated: 24"
#
#
# [1] "Mast cells --> Fibroblasts - Top ranked ligands: 249"
# [1] "Mast cells --> Fibroblasts - Thereof upregulated: 23"
#
#
# [1] "B cells --> Fibroblasts - Top ranked ligands: 249"
# [1] "B cells --> Fibroblasts - Thereof upregulated: 12"
#
#
# [1] "Plasma cells --> Fibroblasts - Top ranked ligands: 249"
# [1] "Plasma cells --> Fibroblasts - Thereof upregulated: 6"
#
#
# [1] "T cells --> Fibroblasts - Top ranked ligands: 249"
# [1] "T cells --> Fibroblasts - Thereof upregulated: 8"
#
#
# [1] "NK cells --> Fibroblasts - Top ranked ligands: 249"
# [1] "NK cells --> Fibroblasts - Thereof upregulated: 14"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_Fibroblasts.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_Fibroblasts.csv"
# [1] "SMC/Pericytes (IPF vs. healthy): Proceeding with geneset of interest of length: 617"
# [1] "Using 617 genes differently regulated genes in SMC/Pericytes (SMC/Pericytes (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 104"
# [1] "Potential Ligands 237"
# [1] "Top ranked ligands 230"
#
# [1] "Airway Epithelium --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "Airway Epithelium --> SMC/Pericytes - Thereof upregulated: 22"
#
#
# [1] "Alveolar Epithelium --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "Alveolar Epithelium --> SMC/Pericytes - Thereof upregulated: 53"
#
#
# [1] "capillary EC --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "capillary EC --> SMC/Pericytes - Thereof upregulated: 40"
#
#
# [1] "vascular EC --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "vascular EC --> SMC/Pericytes - Thereof upregulated: 26"
#
#
# [1] "lymphatic EC --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "lymphatic EC --> SMC/Pericytes - Thereof upregulated: 16"
#
#
# [1] "Fibroblasts --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "Fibroblasts --> SMC/Pericytes - Thereof upregulated: 58"
#
#
# [1] "SMC/Pericytes --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "SMC/Pericytes --> SMC/Pericytes - Thereof upregulated: 50"
#
#
# [1] "Monocytes --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "Monocytes --> SMC/Pericytes - Thereof upregulated: 19"
#
#
# [1] "Macrophages --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "Macrophages --> SMC/Pericytes - Thereof upregulated: 24"
#
#
# [1] "DC --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "DC --> SMC/Pericytes - Thereof upregulated: 23"
#
#
# [1] "Mast cells --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "Mast cells --> SMC/Pericytes - Thereof upregulated: 22"
#
#
# [1] "B cells --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "B cells --> SMC/Pericytes - Thereof upregulated: 14"
#
#
# [1] "Plasma cells --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "Plasma cells --> SMC/Pericytes - Thereof upregulated: 9"
#
#
# [1] "T cells --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "T cells --> SMC/Pericytes - Thereof upregulated: 10"
#
#
# [1] "NK cells --> SMC/Pericytes - Top ranked ligands: 230"
# [1] "NK cells --> SMC/Pericytes - Thereof upregulated: 13"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_SMC_Pericytes.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_SMC_Pericytes.csv"
# [1] "Monocytes (IPF vs. healthy): Proceeding with geneset of interest of length: 384"
# [1] "Using 384 genes differently regulated genes in Monocytes (Monocytes (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 153"
# [1] "Potential Ligands 228"
# [1] "Top ranked ligands 162"
#
# [1] "Airway Epithelium --> Monocytes - Top ranked ligands: 162"
# [1] "Airway Epithelium --> Monocytes - Thereof upregulated: 11"
#
#
# [1] "Alveolar Epithelium --> Monocytes - Top ranked ligands: 162"
# [1] "Alveolar Epithelium --> Monocytes - Thereof upregulated: 29"
#
#
# [1] "capillary EC --> Monocytes - Top ranked ligands: 162"
# [1] "capillary EC --> Monocytes - Thereof upregulated: 32"
#
#
# [1] "vascular EC --> Monocytes - Top ranked ligands: 162"
# [1] "vascular EC --> Monocytes - Thereof upregulated: 17"
#
#
# [1] "lymphatic EC --> Monocytes - Top ranked ligands: 162"
# [1] "lymphatic EC --> Monocytes - Thereof upregulated: 10"
#
#
# [1] "Fibroblasts --> Monocytes - Top ranked ligands: 162"
# [1] "Fibroblasts --> Monocytes - Thereof upregulated: 42"
#
#
# [1] "SMC/Pericytes --> Monocytes - Top ranked ligands: 162"
# [1] "SMC/Pericytes --> Monocytes - Thereof upregulated: 33"
#
#
# [1] "Monocytes --> Monocytes - Top ranked ligands: 162"
# [1] "Monocytes --> Monocytes - Thereof upregulated: 13"
#
#
# [1] "Macrophages --> Monocytes - Top ranked ligands: 162"
# [1] "Macrophages --> Monocytes - Thereof upregulated: 21"
#
#
# [1] "DC --> Monocytes - Top ranked ligands: 162"
# [1] "DC --> Monocytes - Thereof upregulated: 17"
#
#
# [1] "Mast cells --> Monocytes - Top ranked ligands: 162"
# [1] "Mast cells --> Monocytes - Thereof upregulated: 17"
#
#
# [1] "B cells --> Monocytes - Top ranked ligands: 162"
# [1] "B cells --> Monocytes - Thereof upregulated: 7"
#
#
# [1] "Plasma cells --> Monocytes - Top ranked ligands: 162"
# [1] "Plasma cells --> Monocytes - Thereof upregulated: 5"
#
#
# [1] "T cells --> Monocytes - Top ranked ligands: 162"
# [1] "T cells --> Monocytes - Thereof upregulated: 11"
#
#
# [1] "NK cells --> Monocytes - Top ranked ligands: 162"
# [1] "NK cells --> Monocytes - Thereof upregulated: 11"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_Monocytes.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_Monocytes.csv"
# [1] "Macrophages (IPF vs. healthy): Proceeding with geneset of interest of length: 506"
# [1] "Using 506 genes differently regulated genes in Macrophages (Macrophages (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 205"
# [1] "Potential Ligands 257"
# [1] "Top ranked ligands 1"
#
# [1] "Airway Epithelium --> Macrophages - Top ranked ligands: 1"
# [1] "Airway Epithelium --> Macrophages - Thereof upregulated: 0"
#
#
# [1] "Alveolar Epithelium --> Macrophages - Top ranked ligands: 1"
# [1] "Alveolar Epithelium --> Macrophages - Thereof upregulated: 0"
#
#
# [1] "capillary EC --> Macrophages - Top ranked ligands: 1"
# [1] "capillary EC --> Macrophages - Thereof upregulated: 0"
#
#
# [1] "vascular EC --> Macrophages - Top ranked ligands: 1"
# [1] "vascular EC --> Macrophages - Thereof upregulated: 0"
#
#
# [1] "lymphatic EC --> Macrophages - Top ranked ligands: 1"
# [1] "lymphatic EC --> Macrophages - Thereof upregulated: 0"
#
#
# [1] "Fibroblasts --> Macrophages - Top ranked ligands: 1"
# [1] "Fibroblasts --> Macrophages - Thereof upregulated: 0"
#
#
# [1] "SMC/Pericytes --> Macrophages - Top ranked ligands: 1"
# [1] "SMC/Pericytes --> Macrophages - Thereof upregulated: 0"
#
#
# [1] "Monocytes --> Macrophages - Top ranked ligands: 1"
# [1] "Monocytes --> Macrophages - Thereof upregulated: 0"
#
#
# [1] "Macrophages --> Macrophages - Top ranked ligands: 1"
# [1] "Macrophages --> Macrophages - Thereof upregulated: 0"
#
#
# [1] "DC --> Macrophages - Top ranked ligands: 1"
# [1] "DC --> Macrophages - Thereof upregulated: 1"
#
#
# [1] "Mast cells --> Macrophages - Top ranked ligands: 1"
# [1] "Mast cells --> Macrophages - Thereof upregulated: 0"
#
#
# [1] "B cells --> Macrophages - Top ranked ligands: 1"
# [1] "B cells --> Macrophages - Thereof upregulated: 1"
#
#
# [1] "Plasma cells --> Macrophages - Top ranked ligands: 1"
# [1] "Plasma cells --> Macrophages - Thereof upregulated: 0"
#
#
# [1] "T cells --> Macrophages - Top ranked ligands: 1"
# [1] "T cells --> Macrophages - Thereof upregulated: 1"
#
#
# [1] "NK cells --> Macrophages - Top ranked ligands: 1"
# [1] "NK cells --> Macrophages - Thereof upregulated: 0"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_Macrophages.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_Macrophages.csv"
# [1] "DC (IPF vs. healthy): Proceeding with geneset of interest of length: 422"
# [1] "Using 422 genes differently regulated genes in DC (DC (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 185"
# [1] "Potential Ligands 249"
# [1] "Top ranked ligands 6"
#
# [1] "Airway Epithelium --> DC - Top ranked ligands: 6"
# [1] "Airway Epithelium --> DC - Thereof upregulated: 0"
#
#
# [1] "Alveolar Epithelium --> DC - Top ranked ligands: 6"
# [1] "Alveolar Epithelium --> DC - Thereof upregulated: 2"
#
#
# [1] "capillary EC --> DC - Top ranked ligands: 6"
# [1] "capillary EC --> DC - Thereof upregulated: 2"
#
#
# [1] "vascular EC --> DC - Top ranked ligands: 6"
# [1] "vascular EC --> DC - Thereof upregulated: 1"
#
#
# [1] "lymphatic EC --> DC - Top ranked ligands: 6"
# [1] "lymphatic EC --> DC - Thereof upregulated: 0"
#
#
# [1] "Fibroblasts --> DC - Top ranked ligands: 6"
# [1] "Fibroblasts --> DC - Thereof upregulated: 4"
#
#
# [1] "SMC/Pericytes --> DC - Top ranked ligands: 6"
# [1] "SMC/Pericytes --> DC - Thereof upregulated: 2"
#
#
# [1] "Monocytes --> DC - Top ranked ligands: 6"
# [1] "Monocytes --> DC - Thereof upregulated: 0"
#
#
# [1] "Macrophages --> DC - Top ranked ligands: 6"
# [1] "Macrophages --> DC - Thereof upregulated: 2"
#
#
# [1] "DC --> DC - Top ranked ligands: 6"
# [1] "DC --> DC - Thereof upregulated: 2"
#
#
# [1] "Mast cells --> DC - Top ranked ligands: 6"
# [1] "Mast cells --> DC - Thereof upregulated: 0"
#
#
# [1] "B cells --> DC - Top ranked ligands: 6"
# [1] "B cells --> DC - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> DC - Top ranked ligands: 6"
# [1] "Plasma cells --> DC - Thereof upregulated: 0"
#
#
# [1] "T cells --> DC - Top ranked ligands: 6"
# [1] "T cells --> DC - Thereof upregulated: 0"
#
#
# [1] "NK cells --> DC - Top ranked ligands: 6"
# [1] "NK cells --> DC - Thereof upregulated: 0"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_DC.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_DC.csv"
# [1] "Mast cells (IPF vs. healthy): Proceeding with geneset of interest of length: 327"
# [1] "Using 327 genes differently regulated genes in Mast cells (Mast cells (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 48"
# [1] "Potential Ligands 131"
# [1] "Top ranked ligands 125"
#
# [1] "Airway Epithelium --> Mast cells - Top ranked ligands: 125"
# [1] "Airway Epithelium --> Mast cells - Thereof upregulated: 11"
#
#
# [1] "Alveolar Epithelium --> Mast cells - Top ranked ligands: 125"
# [1] "Alveolar Epithelium --> Mast cells - Thereof upregulated: 34"
#
#
# [1] "capillary EC --> Mast cells - Top ranked ligands: 125"
# [1] "capillary EC --> Mast cells - Thereof upregulated: 19"
#
#
# [1] "vascular EC --> Mast cells - Top ranked ligands: 125"
# [1] "vascular EC --> Mast cells - Thereof upregulated: 11"
#
#
# [1] "lymphatic EC --> Mast cells - Top ranked ligands: 125"
# [1] "lymphatic EC --> Mast cells - Thereof upregulated: 5"
#
#
# [1] "Fibroblasts --> Mast cells - Top ranked ligands: 125"
# [1] "Fibroblasts --> Mast cells - Thereof upregulated: 37"
#
#
# [1] "SMC/Pericytes --> Mast cells - Top ranked ligands: 125"
# [1] "SMC/Pericytes --> Mast cells - Thereof upregulated: 33"
#
#
# [1] "Monocytes --> Mast cells - Top ranked ligands: 125"
# [1] "Monocytes --> Mast cells - Thereof upregulated: 9"
#
#
# [1] "Macrophages --> Mast cells - Top ranked ligands: 125"
# [1] "Macrophages --> Mast cells - Thereof upregulated: 17"
#
#
# [1] "DC --> Mast cells - Top ranked ligands: 125"
# [1] "DC --> Mast cells - Thereof upregulated: 16"
#
#
# [1] "Mast cells --> Mast cells - Top ranked ligands: 125"
# [1] "Mast cells --> Mast cells - Thereof upregulated: 19"
#
#
# [1] "B cells --> Mast cells - Top ranked ligands: 125"
# [1] "B cells --> Mast cells - Thereof upregulated: 9"
#
#
# [1] "Plasma cells --> Mast cells - Top ranked ligands: 125"
# [1] "Plasma cells --> Mast cells - Thereof upregulated: 5"
#
#
# [1] "T cells --> Mast cells - Top ranked ligands: 125"
# [1] "T cells --> Mast cells - Thereof upregulated: 5"
#
#
# [1] "NK cells --> Mast cells - Top ranked ligands: 125"
# [1] "NK cells --> Mast cells - Thereof upregulated: 11"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_Mast_cells.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_Mast_cells.csv"
# [1] "B cells (IPF vs. healthy): Proceeding with geneset of interest of length: 690"
# [1] "Using 690 genes differently regulated genes in B cells (B cells (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 79"
# [1] "Potential Ligands 178"
# [1] "Top ranked ligands 145"
#
# [1] "Airway Epithelium --> B cells - Top ranked ligands: 145"
# [1] "Airway Epithelium --> B cells - Thereof upregulated: 12"
#
#
# [1] "Alveolar Epithelium --> B cells - Top ranked ligands: 145"
# [1] "Alveolar Epithelium --> B cells - Thereof upregulated: 31"
#
#
# [1] "capillary EC --> B cells - Top ranked ligands: 145"
# [1] "capillary EC --> B cells - Thereof upregulated: 28"
#
#
# [1] "vascular EC --> B cells - Top ranked ligands: 145"
# [1] "vascular EC --> B cells - Thereof upregulated: 13"
#
#
# [1] "lymphatic EC --> B cells - Top ranked ligands: 145"
# [1] "lymphatic EC --> B cells - Thereof upregulated: 7"
#
#
# [1] "Fibroblasts --> B cells - Top ranked ligands: 145"
# [1] "Fibroblasts --> B cells - Thereof upregulated: 36"
#
#
# [1] "SMC/Pericytes --> B cells - Top ranked ligands: 145"
# [1] "SMC/Pericytes --> B cells - Thereof upregulated: 31"
#
#
# [1] "Monocytes --> B cells - Top ranked ligands: 145"
# [1] "Monocytes --> B cells - Thereof upregulated: 10"
#
#
# [1] "Macrophages --> B cells - Top ranked ligands: 145"
# [1] "Macrophages --> B cells - Thereof upregulated: 12"
#
#
# [1] "DC --> B cells - Top ranked ligands: 145"
# [1] "DC --> B cells - Thereof upregulated: 16"
#
#
# [1] "Mast cells --> B cells - Top ranked ligands: 145"
# [1] "Mast cells --> B cells - Thereof upregulated: 14"
#
#
# [1] "B cells --> B cells - Top ranked ligands: 145"
# [1] "B cells --> B cells - Thereof upregulated: 10"
#
#
# [1] "Plasma cells --> B cells - Top ranked ligands: 145"
# [1] "Plasma cells --> B cells - Thereof upregulated: 7"
#
#
# [1] "T cells --> B cells - Top ranked ligands: 145"
# [1] "T cells --> B cells - Thereof upregulated: 6"
#
#
# [1] "NK cells --> B cells - Top ranked ligands: 145"
# [1] "NK cells --> B cells - Thereof upregulated: 9"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_B_cells.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_B_cells.csv"
# [1] "Plasma cells (IPF vs. healthy): Proceeding with geneset of interest of length: 47"
# [1] "Using 47 genes differently regulated genes in Plasma cells (Plasma cells (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 52"
# [1] "Potential Ligands 129"
# [1] "Top ranked ligands 0"
#
# [1] "Airway Epithelium --> Plasma cells - Top ranked ligands: 0"
# [1] "Airway Epithelium --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "Alveolar Epithelium --> Plasma cells - Top ranked ligands: 0"
# [1] "Alveolar Epithelium --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "capillary EC --> Plasma cells - Top ranked ligands: 0"
# [1] "capillary EC --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "vascular EC --> Plasma cells - Top ranked ligands: 0"
# [1] "vascular EC --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "lymphatic EC --> Plasma cells - Top ranked ligands: 0"
# [1] "lymphatic EC --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "Fibroblasts --> Plasma cells - Top ranked ligands: 0"
# [1] "Fibroblasts --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "SMC/Pericytes --> Plasma cells - Top ranked ligands: 0"
# [1] "SMC/Pericytes --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "Monocytes --> Plasma cells - Top ranked ligands: 0"
# [1] "Monocytes --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "Macrophages --> Plasma cells - Top ranked ligands: 0"
# [1] "Macrophages --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "DC --> Plasma cells - Top ranked ligands: 0"
# [1] "DC --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "Mast cells --> Plasma cells - Top ranked ligands: 0"
# [1] "Mast cells --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "B cells --> Plasma cells - Top ranked ligands: 0"
# [1] "B cells --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "Plasma cells --> Plasma cells - Top ranked ligands: 0"
# [1] "Plasma cells --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "T cells --> Plasma cells - Top ranked ligands: 0"
# [1] "T cells --> Plasma cells - Thereof upregulated: 0"
#
#
# [1] "NK cells --> Plasma cells - Top ranked ligands: 0"
# [1] "NK cells --> Plasma cells - Thereof upregulated: 0"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_Plasma_cells.csv"
# Warning message:
# “Unknown or uninitialised column: `weight`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# Warning message:
# “Unknown or uninitialised column: `ligand`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# Warning message:
# “Unknown or uninitialised column: `ligand`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# Warning message:
# “Unknown or uninitialised column: `ligand`.”
# Warning message:
# “Unknown or uninitialised column: `target`.”
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_Plasma_cells.csv"
# [1] "T cells (IPF vs. healthy): Proceeding with geneset of interest of length: 296"
# [1] "Using 296 genes differently regulated genes in T cells (T cells (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 99"
# [1] "Potential Ligands 189"
# [1] "Top ranked ligands 182"
#
# [1] "Airway Epithelium --> T cells - Top ranked ligands: 182"
# [1] "Airway Epithelium --> T cells - Thereof upregulated: 14"
#
#
# [1] "Alveolar Epithelium --> T cells - Top ranked ligands: 182"
# [1] "Alveolar Epithelium --> T cells - Thereof upregulated: 42"
#
#
# [1] "capillary EC --> T cells - Top ranked ligands: 182"
# [1] "capillary EC --> T cells - Thereof upregulated: 30"
#
#
# [1] "vascular EC --> T cells - Top ranked ligands: 182"
# [1] "vascular EC --> T cells - Thereof upregulated: 23"
#
#
# [1] "lymphatic EC --> T cells - Top ranked ligands: 182"
# [1] "lymphatic EC --> T cells - Thereof upregulated: 10"
#
#
# [1] "Fibroblasts --> T cells - Top ranked ligands: 182"
# [1] "Fibroblasts --> T cells - Thereof upregulated: 51"
#
#
# [1] "SMC/Pericytes --> T cells - Top ranked ligands: 182"
# [1] "SMC/Pericytes --> T cells - Thereof upregulated: 45"
#
#
# [1] "Monocytes --> T cells - Top ranked ligands: 182"
# [1] "Monocytes --> T cells - Thereof upregulated: 14"
#
#
# [1] "Macrophages --> T cells - Top ranked ligands: 182"
# [1] "Macrophages --> T cells - Thereof upregulated: 20"
#
#
# [1] "DC --> T cells - Top ranked ligands: 182"
# [1] "DC --> T cells - Thereof upregulated: 24"
#
#
# [1] "Mast cells --> T cells - Top ranked ligands: 182"
# [1] "Mast cells --> T cells - Thereof upregulated: 20"
#
#
# [1] "B cells --> T cells - Top ranked ligands: 182"
# [1] "B cells --> T cells - Thereof upregulated: 15"
#
#
# [1] "Plasma cells --> T cells - Top ranked ligands: 182"
# [1] "Plasma cells --> T cells - Thereof upregulated: 7"
#
#
# [1] "T cells --> T cells - Top ranked ligands: 182"
# [1] "T cells --> T cells - Thereof upregulated: 10"
#
#
# [1] "NK cells --> T cells - Top ranked ligands: 182"
# [1] "NK cells --> T cells - Thereof upregulated: 13"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_T_cells.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_T_cells.csv"
# [1] "NK cells (IPF vs. healthy): Proceeding with geneset of interest of length: 478"
# [1] "Using 478 genes differently regulated genes in NK cells (NK cells (IPF vs. healthy))"
# [1] "Expressed Ligands 347"
# [1] "Expressed Receptors 102"
# [1] "Potential Ligands 193"
# [1] "Top ranked ligands 181"
#
# [1] "Airway Epithelium --> NK cells - Top ranked ligands: 181"
# [1] "Airway Epithelium --> NK cells - Thereof upregulated: 15"
#
#
# [1] "Alveolar Epithelium --> NK cells - Top ranked ligands: 181"
# [1] "Alveolar Epithelium --> NK cells - Thereof upregulated: 41"
#
#
# [1] "capillary EC --> NK cells - Top ranked ligands: 181"
# [1] "capillary EC --> NK cells - Thereof upregulated: 29"
#
#
# [1] "vascular EC --> NK cells - Top ranked ligands: 181"
# [1] "vascular EC --> NK cells - Thereof upregulated: 21"
#
#
# [1] "lymphatic EC --> NK cells - Top ranked ligands: 181"
# [1] "lymphatic EC --> NK cells - Thereof upregulated: 11"
#
#
# [1] "Fibroblasts --> NK cells - Top ranked ligands: 181"
# [1] "Fibroblasts --> NK cells - Thereof upregulated: 50"
#
#
# [1] "SMC/Pericytes --> NK cells - Top ranked ligands: 181"
# [1] "SMC/Pericytes --> NK cells - Thereof upregulated: 39"
#
#
# [1] "Monocytes --> NK cells - Top ranked ligands: 181"
# [1] "Monocytes --> NK cells - Thereof upregulated: 17"
#
#
# [1] "Macrophages --> NK cells - Top ranked ligands: 181"
# [1] "Macrophages --> NK cells - Thereof upregulated: 17"
#
#
# [1] "DC --> NK cells - Top ranked ligands: 181"
# [1] "DC --> NK cells - Thereof upregulated: 22"
#
#
# [1] "Mast cells --> NK cells - Top ranked ligands: 181"
# [1] "Mast cells --> NK cells - Thereof upregulated: 20"
#
#
# [1] "B cells --> NK cells - Top ranked ligands: 181"
# [1] "B cells --> NK cells - Thereof upregulated: 10"
#
#
# [1] "Plasma cells --> NK cells - Top ranked ligands: 181"
# [1] "Plasma cells --> NK cells - Thereof upregulated: 6"
#
#
# [1] "T cells --> NK cells - Top ranked ligands: 181"
# [1] "T cells --> NK cells - Thereof upregulated: 9"
#
#
# [1] "NK cells --> NK cells - Top ranked ligands: 181"
# [1] "NK cells --> NK cells - Thereof upregulated: 16"
#
# [1] "Writing ligand activity table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_act_NK_cells.csv"
# [1] "Writing ligand target matrix table to:  /home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo/01_data/NicheNet_outputs/ligand_activities_FC_CC/nichenet_ligand_target_matrix_NK_cells.csv"

# %%
write.csv(quant_results_df, paste0(results_dir, '220207_quant_crosstalk_IPF_healthy.csv'))
quant_results_df
# Out:
#                     Airway Epithelium Alveolar Epithelium capillary EC
# Airway Epithelium   0                 21                  18
# Alveolar Epithelium 0                 50                  46
# capillary EC        0                 41                  38
# vascular EC         0                 27                  24
# lymphatic EC        0                 15                  14
# Fibroblasts         0                 61                  55
# SMC/Pericytes       0                 50                  49
# Monocytes           0                 17                  15
# Macrophages         0                 22                  22
# DC                  0                 23                  21
# Mast cells          0                 23                  19
# B cells             0                 14                  12
# Plasma cells        0                  7                   6
# T cells             0                  9                   7
# NK cells            0                 14                  11
#                     vascular EC lymphatic EC Fibroblasts SMC/Pericytes
# Airway Epithelium   20          0            25          22
# Alveolar Epithelium 51          0            56          53
# capillary EC        40          0            46          40
# vascular EC         26          0            29          26
# lymphatic EC        15          0            15          16
# Fibroblasts         57          1            67          58
# SMC/Pericytes       47          0            53          50
# Monocytes           17          0            17          19
# Macrophages         22          0            25          24
# DC                  20          0            24          23
# Mast cells          26          0            23          22
# B cells             13          0            12          14
# Plasma cells         6          0             6           9
# T cells              8          0             8          10
# NK cells            11          0            14          13
#                     Monocytes Macrophages DC Mast cells B cells Plasma cells
# Airway Epithelium   11        0           0  11         12      0
# Alveolar Epithelium 29        0           2  34         31      0
# capillary EC        32        0           2  19         28      0
# vascular EC         17        0           1  11         13      0
# lymphatic EC        10        0           0   5          7      0
# Fibroblasts         42        0           4  37         36      0
# SMC/Pericytes       33        0           2  33         31      0
# Monocytes           13        0           0   9         10      0
# Macrophages         21        0           2  17         12      0
# DC                  17        1           2  16         16      0
# Mast cells          17        0           0  19         14      0
# B cells              7        1           0   9         10      0
# Plasma cells         5        0           0   5          7      0
# T cells             11        1           0   5          6      0
# NK cells            11        0           0  11          9      0
#                     T cells NK cells
# Airway Epithelium   14      15
# Alveolar Epithelium 42      41
# capillary EC        30      29
# vascular EC         23      21
# lymphatic EC        10      11
# Fibroblasts         51      50
# SMC/Pericytes       45      39
# Monocytes           14      17
# Macrophages         20      17
# DC                  24      22
# Mast cells          20      20
# B cells             15      10
# Plasma cells         7       6
# T cells             10       9
# NK cells            13      16

# %%
write.csv(qual_results_df, paste0(results_dir, '220207_qual_crosstalk_IPF_healthy.csv'))
qual_results_df
# Out:
#                     Airway Epithelium Alveolar Epithelium capillary EC
# Airway Epithelium   0                 1.2541061           1.0084967
# Alveolar Epithelium 0                 2.9020258           2.3606030
# capillary EC        0                 2.2262758           1.8116763
# vascular EC         0                 1.5145610           1.1393725
# lymphatic EC        0                 0.9740630           0.7995502
# Fibroblasts         0                 4.0571411           3.2959720
# SMC/Pericytes       0                 2.2238301           2.1167650
# Monocytes           0                 1.3258681           1.0706921
# Macrophages         0                 1.5022383           1.3045644
# DC                  0                 0.9723152           0.7184876
# Mast cells          0                 1.0828140           0.7166309
# B cells             0                 0.7636488           0.4456143
# Plasma cells        0                 0.3858889           0.2677880
# T cells             0                 0.7683558           0.5267449
# NK cells            0                 1.2288277           0.9276982
#                     vascular EC lymphatic EC Fibroblasts SMC/Pericytes
# Airway Epithelium   0.7288352   0.00000000   1.0182716   0.9933199
# Alveolar Epithelium 1.6020304   0.00000000   2.3003470   2.5419929
# capillary EC        1.1621441   0.00000000   1.7619862   1.8262043
# vascular EC         0.7627147   0.00000000   1.2447438   1.1920753
# lymphatic EC        0.5556148   0.00000000   0.7590037   0.9059968
# Fibroblasts         2.1584393   0.05090826   3.4225446   3.2365885
# SMC/Pericytes       1.1523576   0.00000000   1.8852263   1.8877700
# Monocytes           0.7335577   0.00000000   1.0442990   1.4068405
# Macrophages         0.8080147   0.00000000   1.2543075   1.3785651
# DC                  0.5452446   0.00000000   0.7537191   0.9003395
# Mast cells          0.7342108   0.00000000   0.8570629   0.8659451
# B cells             0.3803729   0.00000000   0.3543582   0.6400167
# Plasma cells        0.1751446   0.00000000   0.2090759   0.4541828
# T cells             0.3644911   0.00000000   0.5213811   0.7149002
# NK cells            0.5581458   0.00000000   0.8851519   0.9692215
#                     Monocytes Macrophages DC         Mast cells B cells
# Airway Epithelium   0.3027240 0.00000000  0.00000000 0.4894918  0.4344750
# Alveolar Epithelium 0.7938084 0.00000000  0.02032307 1.3986479  1.0005040
# capillary EC        0.8929216 0.00000000  0.02581323 0.6542556  0.7512418
# vascular EC         0.6529527 0.00000000  0.06642884 0.4217670  0.4444174
# lymphatic EC        0.4328953 0.00000000  0.00000000 0.3042244  0.3450289
# Fibroblasts         1.6134819 0.00000000  0.15408308 1.9787909  1.4012248
# SMC/Pericytes       0.9046159 0.00000000  0.02216873 0.9087499  0.7728042
# Monocytes           0.6799049 0.00000000  0.00000000 0.5108892  0.3162811
# Macrophages         0.6263757 0.00000000  0.01725455 0.7779727  0.3641936
# DC                  0.3856434 0.03780410  0.02936613 0.3924075  0.3545239
# Mast cells          0.6034512 0.00000000  0.00000000 0.5741652  0.3163642
# B cells             0.3798044 0.02558082  0.00000000 0.3785283  0.3596508
# Plasma cells        0.1456193 0.00000000  0.00000000 0.1935207  0.1667822
# T cells             0.6285052 0.05436297  0.00000000 0.3501229  0.2939495
# NK cells            0.6081962 0.00000000  0.00000000 0.6256418  0.3794450
#                     Plasma cells T cells   NK cells
# Airway Epithelium   0            0.6671166 0.6721338
# Alveolar Epithelium 0            2.0837903 1.6148609
# capillary EC        0            1.4940101 1.1055799
# vascular EC         0            1.1739118 0.8390571
# lymphatic EC        0            0.7132733 0.6067644
# Fibroblasts         0            3.2174505 2.4536372
# SMC/Pericytes       0            1.8317527 1.2082657
# Monocytes           0            0.9296119 0.9139480
# Macrophages         0            1.0823083 0.8093529
# DC                  0            0.9417982 0.6773241
# Mast cells          0            0.7927706 0.5806357
# B cells             0            0.8252301 0.4109796
# Plasma cells        0            0.3235013 0.2051063
# T cells             0            0.8175503 0.5630769
# NK cells            0            0.8706802 1.0362687
