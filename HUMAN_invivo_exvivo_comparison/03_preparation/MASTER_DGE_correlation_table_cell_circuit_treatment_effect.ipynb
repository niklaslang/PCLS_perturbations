# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# ## Create combined in vivo + ex vivo DGE tables for correlation analyses

# %%
## directory paths
dge_dir = '/home/niklas/projects/niche_environments_FIBROSIS/PCLS_human/01_data/ASK_joint/DGE_treatment_vs_FC/221204_PCLS_human_ASK_joint_'

# %%
cell_type_names = ['Aberrant_Basaloid','ectopic_EC','Myofibroblasts','Pericytes','Profibrotic_Macrophages']

# %%
## initialize master tables
master = pd.DataFrame()
master_filtered_pct_expressed = pd.DataFrame()
master_filtered_pval = pd.DataFrame()

# %%
for ct in cell_type_names:
    ## read data
    cmp4_table = pd.read_csv(dge_dir + ct + '_FC+CMP4_vs_FC_DGE_results.csv', index_col = 0)
    nintedanib_table = pd.read_csv(dge_dir + ct + '_FC+Nintedanib_vs_FC_DGE_results.csv', index_col = 0)
    
    ## select important columns only
    cmp4_table = cmp4_table[['log2fc','qval','pct.FCs','pct.FC+CMP4s']]
    nintedanib_table = nintedanib_table[['log2fc','qval','pct.FCs','pct.FC+Nintedanibs']]
    
    ### filter DGE tables by pct expressed
    #cmp4_table = cmp4_table[cmp4_table['pct.FC+CMP4'] > 0.10]
    #cmp4_table = cmp4_table[cmp4_table['pct.FCs'] > 0.10]
    #nintedanib_table = nintedanib_table[nintedanib_table['pct.FC+Nintedanib'] > 0.10]
    #nintedanib_table = nintedanib_table[nintedanib_table['pct.FCs'] > 0.10]
    
    ## replace exorbitant high logFC values
    cmp4_table['log2fc'] = [5 if logfc > 5 else logfc for logfc in cmp4_table['log2fc']]
    cmp4_table['log2fc'] = [-5 if logfc < -5 else logfc for logfc in cmp4_table['log2fc']]
    nintedanib_table['log2fc'] = [5 if logfc > 5 else logfc for logfc in nintedanib_table['log2fc']]
    nintedanib_table['log2fc'] = [-5 if logfc < -5 else logfc for logfc in nintedanib_table['log2fc']]
    
    ## rename columns
    cmp4_table.rename(columns = {'log2fc':str(ct +'_CMP4_log2FC'),
                                   'qval':str(ct +'_CMP4_pval_adj'),
                                   'pct.FCs':str(ct +'_CMP4_pct_FC'),
                                   'pct.FC+CMP4s':str(ct +'_CMP4_pct_FC_CMP4')}, inplace = True)
    nintedanib_table.rename(columns = {'log2fc':str(ct +'_Nintedanib_log2FC'),
                                   'qval':str(ct +'_Nintedanib_pval_adj'),
                                   'pct.CCs':str(ct +'_Nintedanib_pct_FC'),
                                   'pct.FC+Nintedanibs':str(ct +'_Nintedanib_pct_FC_Nintedanib')}, inplace = True)
    
    
    ## create separate master table filtered by qval
    cmp4_table_filtered_pval = cmp4_table[cmp4_table[str(ct +'_CMP4_pval_adj')] < 0.05 ]
    nintedanib_table_filtered_pval = nintedanib_table[nintedanib_table[str(ct +'_Nintedanib_pval_adj')] < 0.05 ]
    
    ## create separate master table filtered by pct expressed (in addition to qval)
    cmp4_table_filtered_pct_expressed = cmp4_table_filtered_pval[cmp4_table_filtered_pval[str(ct +'_CMP4_pct_FC_CMP4')] > 0.1]
    nintedanib_table_filtered_pct_expressed = nintedanib_table_filtered_pval[nintedanib_table_filtered_pval[str(ct +'_Nintedanib_pct_FC_Nintedanib')] > 0.1]
    
    ## merge tables
    comparison = pd.concat([cmp4_table, nintedanib_table], axis=1, join='outer')
    comparison_filtered_pval  = pd.concat([cmp4_table_filtered_pval, nintedanib_table_filtered_pval], axis=1, join='outer')
    comparison_filtered_pct_expressed = pd.concat([cmp4_table_filtered_pct_expressed, nintedanib_table_filtered_pct_expressed], axis=1, join='outer')
    
    ### save results table
    #csv_dir = str('/home/niklas/projects/niche_environments_FIBROSIS/PCLS_human/01_data/ASK_joint/DGE_correlation_tables/221214_dge_correlation_table_' + ct + '.csv')
    #comparison.to_csv(csv_dir, index = True)
    
    ## add column to 'MASTER' table
    master = pd.concat([master, comparison], axis=1, join='outer')
    master_filtered_pct_expressed = pd.concat([master_filtered_pct_expressed, comparison_filtered_pct_expressed], axis=1, join='outer')
    master_filtered_pval = pd.concat([master_filtered_pval, comparison_filtered_pval], axis=1, join='outer')

# %%
master.head(15)
# Out:
#             Aberrant_Basaloid_CMP4_log2FC  Aberrant_Basaloid_CMP4_pval_adj  \
# gene
# ZNF724                           5.000000                         0.000000
# NDP                              5.000000                         0.000000
# GABRP                            3.667137                         0.002634
# OR5AU1                           3.116170                         0.059704
# NEB                              2.916769                         0.001129
# HP                               2.910620                         0.077657
# CHIA                             2.835474                         0.074358
# SOD2-1                           2.810122                         0.007675
# AC011498.4                       2.680487                         0.000612
# MYLK3                            2.648371                         0.090089
# SYCP3                            2.450476                         0.078132
# FBXO41                           2.278443                         0.080534
# FAM177B                          2.215636                         0.000936
# MNX1                             2.159636                         0.000023
# EYS                              2.145899                         0.000142
#
#             Aberrant_Basaloid_CMP4_pct_FC  Aberrant_Basaloid_CMP4_pct_FC_CMP4  \
# gene
# ZNF724                           0.000000                            0.013661
# NDP                              0.000000                            0.013661
# GABRP                            0.002894                            0.027322
# OR5AU1                           0.001447                            0.016393
# NEB                              0.001447                            0.013661
# HP                               0.002894                            0.013661
# CHIA                             0.001447                            0.016393
# SOD2-1                           0.002894                            0.030055
# AC011498.4                       0.005789                            0.043716
# MYLK3                            0.001447                            0.016393
# SYCP3                            0.002894                            0.016393
# FBXO41                           0.002894                            0.016393
# FAM177B                          0.002894                            0.013661
# MNX1                             0.002894                            0.019126
# EYS                              0.002894                            0.024590
#
#             Aberrant_Basaloid_Nintedanib_log2FC  \
# gene
# ZNF724                                 5.000000
# NDP                                         NaN
# GABRP                                  2.397648
# OR5AU1                                      NaN
# NEB                                         NaN
# HP                                          NaN
# CHIA                                        NaN
# SOD2-1                                 1.229754
# AC011498.4                             1.594049
# MYLK3                                       NaN
# SYCP3                                  1.503892
# FBXO41                                 2.302322
# FAM177B                                2.161682
# MNX1                                        NaN
# EYS                                         NaN
#
#             Aberrant_Basaloid_Nintedanib_pval_adj   pct.FCs  \
# gene
# ZNF724                               0.000000e+00  0.000000
# NDP                                           NaN       NaN
# GABRP                                6.153309e-02  0.002894
# OR5AU1                                        NaN       NaN
# NEB                                           NaN       NaN
# HP                                            NaN       NaN
# CHIA                                          NaN       NaN
# SOD2-1                               1.843329e-02  0.002894
# AC011498.4                           5.609099e-07  0.005789
# MYLK3                                         NaN       NaN
# SYCP3                                6.752568e-03  0.002894
# FBXO41                               8.039848e-05  0.002894
# FAM177B                              1.596314e-04  0.002894
# MNX1                                          NaN       NaN
# EYS                                           NaN       NaN
#
#             Aberrant_Basaloid_Nintedanib_pct_FC_Nintedanib  \
# gene
# ZNF724                                            0.020408
# NDP                                                    NaN
# GABRP                                             0.020408
# OR5AU1                                                 NaN
# NEB                                                    NaN
# HP                                                     NaN
# CHIA                                                   NaN
# SOD2-1                                            0.020408
# AC011498.4                                        0.054422
# MYLK3                                                  NaN
# SYCP3                                             0.017007
# FBXO41                                            0.020408
# FAM177B                                           0.030612
# MNX1                                                   NaN
# EYS                                                    NaN
#
#             ectopic_EC_CMP4_log2FC  ectopic_EC_CMP4_pval_adj  ...   pct.FCs  \
# gene                                                          ...
# ZNF724                         NaN                       NaN  ...       NaN
# NDP                            NaN                       NaN  ...       NaN
# GABRP                          NaN                       NaN  ...       NaN
# OR5AU1                         NaN                       NaN  ...       NaN
# NEB                            NaN                       NaN  ...  0.016071
# HP                             NaN                       NaN  ...       NaN
# CHIA                           NaN                       NaN  ...       NaN
# SOD2-1                         NaN                       NaN  ...       NaN
# AC011498.4                     NaN                       NaN  ...       NaN
# MYLK3                          NaN                       NaN  ...       NaN
# SYCP3                          NaN                       NaN  ...       NaN
# FBXO41                         NaN                       NaN  ...       NaN
# FAM177B                        NaN                       NaN  ...       NaN
# MNX1                           NaN                       NaN  ...       NaN
# EYS                            NaN                       NaN  ...       NaN
#
#             Pericytes_Nintedanib_pct_FC_Nintedanib  \
# gene
# ZNF724                                         NaN
# NDP                                            NaN
# GABRP                                          NaN
# OR5AU1                                         NaN
# NEB                                       0.026074
# HP                                             NaN
# CHIA                                           NaN
# SOD2-1                                         NaN
# AC011498.4                                     NaN
# MYLK3                                          NaN
# SYCP3                                          NaN
# FBXO41                                         NaN
# FAM177B                                        NaN
# MNX1                                           NaN
# EYS                                            NaN
#
#             Profibrotic_Macrophages_CMP4_log2FC  \
# gene
# ZNF724                                      NaN
# NDP                                         NaN
# GABRP                                       NaN
# OR5AU1                                      NaN
# NEB                                         NaN
# HP                                          NaN
# CHIA                                        NaN
# SOD2-1                                     -5.0
# AC011498.4                                 -5.0
# MYLK3                                       NaN
# SYCP3                                       NaN
# FBXO41                                      NaN
# FAM177B                                     NaN
# MNX1                                        NaN
# EYS                                         NaN
#
#             Profibrotic_Macrophages_CMP4_pval_adj  \
# gene
# ZNF724                                        NaN
# NDP                                           NaN
# GABRP                                         NaN
# OR5AU1                                        NaN
# NEB                                           NaN
# HP                                            NaN
# CHIA                                          NaN
# SOD2-1                                        0.0
# AC011498.4                                    0.0
# MYLK3                                         NaN
# SYCP3                                         NaN
# FBXO41                                        NaN
# FAM177B                                       NaN
# MNX1                                          NaN
# EYS                                           NaN
#
#             Profibrotic_Macrophages_CMP4_pct_FC  \
# gene
# ZNF724                                      NaN
# NDP                                         NaN
# GABRP                                       NaN
# OR5AU1                                      NaN
# NEB                                         NaN
# HP                                          NaN
# CHIA                                        NaN
# SOD2-1                                 0.005372
# AC011498.4                             0.005372
# MYLK3                                       NaN
# SYCP3                                       NaN
# FBXO41                                      NaN
# FAM177B                                     NaN
# MNX1                                        NaN
# EYS                                         NaN
#
#             Profibrotic_Macrophages_CMP4_pct_FC_CMP4  \
# gene
# ZNF724                                           NaN
# NDP                                              NaN
# GABRP                                            NaN
# OR5AU1                                           NaN
# NEB                                              NaN
# HP                                               NaN
# CHIA                                             NaN
# SOD2-1                                           0.0
# AC011498.4                                       0.0
# MYLK3                                            NaN
# SYCP3                                            NaN
# FBXO41                                           NaN
# FAM177B                                          NaN
# MNX1                                             NaN
# EYS                                              NaN
#
#             Profibrotic_Macrophages_Nintedanib_log2FC  \
# gene
# ZNF724                                            NaN
# NDP                                               NaN
# GABRP                                             NaN
# OR5AU1                                            NaN
# NEB                                          2.136221
# HP                                                NaN
# CHIA                                              NaN
# SOD2-1                                      -5.000000
# AC011498.4                                  -5.000000
# MYLK3                                             NaN
# SYCP3                                             NaN
# FBXO41                                            NaN
# FAM177B                                           NaN
# MNX1                                              NaN
# EYS                                               NaN
#
#             Profibrotic_Macrophages_Nintedanib_pval_adj   pct.FCs  \
# gene
# ZNF724                                              NaN       NaN
# NDP                                                 NaN       NaN
# GABRP                                               NaN       NaN
# OR5AU1                                              NaN       NaN
# NEB                                            0.056988  0.001791
# HP                                                  NaN       NaN
# CHIA                                                NaN       NaN
# SOD2-1                                         0.000000  0.005372
# AC011498.4                                     0.000000  0.005372
# MYLK3                                               NaN       NaN
# SYCP3                                               NaN       NaN
# FBXO41                                              NaN       NaN
# FAM177B                                             NaN       NaN
# MNX1                                                NaN       NaN
# EYS                                                 NaN       NaN
#
#             Profibrotic_Macrophages_Nintedanib_pct_FC_Nintedanib
# gene
# ZNF724                                                    NaN
# NDP                                                       NaN
# GABRP                                                     NaN
# OR5AU1                                                    NaN
# NEB                                                  0.011029
# HP                                                        NaN
# CHIA                                                      NaN
# SOD2-1                                               0.000000
# AC011498.4                                           0.000000
# MYLK3                                                     NaN
# SYCP3                                                     NaN
# FBXO41                                                    NaN
# FAM177B                                                   NaN
# MNX1                                                      NaN
# EYS                                                       NaN
#
# [15 rows x 40 columns]

# %%
master.shape
# Out:
# (14386, 40)

# %%
master_filtered_pct_expressed.shape
# Out:
# (9505, 40)

# %%
master_filtered_pval.shape
# Out:
# (13856, 40)

# %%
## save master tables
csv_dir = str('/home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo_exvivo_comparison/01_data/ASK_joint/221214_ASK_joint_MASTER_dge_table_cell_circuit_treatment.csv')
master.to_csv(csv_dir, index = True)

# %%
master_filtered_pct_expressed.shape
# Out:
# (9505, 40)

# %%
## save master tables
csv_dir = str('/home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo_exvivo_comparison/01_data/ASK_joint/221214_ASK_joint_MASTER_dge_table_cell_circuit_treatment_filtered_pct_expr.csv')
master_filtered_pct_expressed.to_csv(csv_dir, index = True)

# %%
master_filtered_pval.shape
# Out:
# (13856, 40)

# %%
## save master tables
csv_dir = str('/home/niklas/projects/niche_environments_FIBROSIS/HUMAN_invivo_exvivo_comparison/01_data/ASK_joint/221214_ASK_joint_MASTER_dge_table_cell_circuit_treatment_filtered_pval.csv')
master_filtered_pval.to_csv(csv_dir, index = True)
